# %%
from pyspark.sql import SparkSession
import os

# Initialize Spark session with Delta and S3 settings
spark = SparkSession.builder \
    .appName("KinesisToDeltaLake") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0,org.apache.hadoop:hadoop-aws:3.3.2,com.amazonaws:aws-java-sdk-bundle:1.11.1026") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.access.key", os.getenv("AWS_ACCESS_KEY_ID")) \
    .config("spark.hadoop.fs.s3a.secret.key", os.getenv("AWS_SECRET_ACCESS_KEY")) \
    .config("spark.hadoop.fs.s3a.session.token", os.getenv("AWS_SESSION_TOKEN")) \
    .config("spark.hadoop.fs.s3a.endpoint", "s3.amazonaws.com") \
    .config("spark.sql.files.maxPartitionBytes", "134217728") \
    .getOrCreate()
# Out:
# 24/09/30 20:28:11 WARN Utils: Your hostname, Somnium.local resolves to a loopback address: 127.0.0.1; using 172.28.59.194 instead (on interface en0)
# 24/09/30 20:28:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/Users/borja/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/borja/.ivy2/cache
# The jars for the packages stored in: /Users/borja/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# com.amazonaws#aws-java-sdk-bundle added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-bd7cb223-11e7-4c1c-af8b-8e61d450a728;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# 	found org.apache.hadoop#hadoop-aws;3.3.2 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.1026 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# :: resolution report :: resolve 261ms :: artifacts dl 13ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.11.1026 from central in [default]
# 	io.delta#delta-core_2.12;2.4.0 from central in [default]
# 	io.delta#delta-storage;2.4.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.2 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   6   |   0   |   0   |   0   ||   6   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-bd7cb223-11e7-4c1c-af8b-8e61d450a728
# 	confs: [default]
# 	0 artifacts copied, 6 already retrieved (0kB/8ms)
# 24/09/30 20:28:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/09/30 20:28:13 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
import boto3
import json
import time
from dotenv import load_dotenv
from datetime import datetime

# Load environment variables from .env file
load_dotenv()

# Initialize AWS credentials from the .env file
AWS_ACCESS_KEY_ID = os.getenv('AWS_ACCESS_KEY_ID')
AWS_SECRET_ACCESS_KEY = os.getenv('AWS_SECRET_ACCESS_KEY')
AWS_SESSION_TOKEN = os.getenv('AWS_SESSION_TOKEN')
AWS_REGION = os.getenv('AWS_REGION')

# %%
# Initialize boto3 client for Kinesis with your credentials
kinesis_client = boto3.client(
    'kinesis',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    aws_session_token=AWS_SESSION_TOKEN,
    region_name=AWS_REGION
)

# %%
# Function to update order status to "ready_for_dispatch"
def update_order_status(orders):
    for order in orders:
        order['status'] = 'ready_for_dispatch'
    return orders

# Function to write to Delta table
def write_to_delta(df, delta_table_path):
    df.write.format("delta").mode("append").save(delta_table_path)
    print(f"Written {df.count()} records to Delta table.")

# Function to filter only new orders (with status 'in_progress')
def filter_new_orders(orders):
    return [order for order in orders if order['status'] == 'in_progress']

# %%
import boto3
import json
import time


# Function to get the shard iterator
def get_shard_iterator(stream_name, shard_id):
    response = kinesis_client.get_shard_iterator(
        StreamName=stream_name,
        ShardId=shard_id,
        ShardIteratorType='TRIM_HORIZON'  # or 'LATEST' for new records
    )
    return response['ShardIterator']

# Function to read records from the Kinesis stream
def read_kinesis_records(shard_iterator):
    response = kinesis_client.get_records(ShardIterator=shard_iterator, Limit=100)
    records = response['Records']
    return records, response['NextShardIterator']

# Fetch Kinesis records
def fetch_kinesis_records(stream_name, shard_id):
    shard_iterator = get_shard_iterator(stream_name, shard_id)
    
    print("Fetching records from Kinesis stream...")
    records, shard_iterator = read_kinesis_records(shard_iterator)

    # Extract order data from records
    orders = []
    for record in records:
        order_data = record['Data']
        order = json.loads(order_data)
        print("Received order:", order)
        orders.append(order)

    return orders

# %%
delta_table_path_ready_for_dispatch = 's3a://orders-for-dispatch/ready_for_dispatching'

# %%
# Dispatcher function with fetch_kinesis_records integration
def dispatcher():
    stream_name = 'OrderStreamForDispatching'
    shard_id = 'shardId-000000000000'
    max_weight = 100  # Threshold for total weight
    max_volume = 500  # Threshold for total volume
    dispatch_time = datetime.strptime('12:00', '%H:%M').time()  # Dispatch by noon
    order_buffer = []
    
    accumulated_weight = 0
    accumulated_volume = 0

    print("Starting dispatcher...")

    while True:
        # Fetch records from Kinesis
        orders = fetch_kinesis_records(stream_name, shard_id)

        for order in orders:
            order_buffer.append(order)
            accumulated_weight += order['order']['weight']
            accumulated_volume += order['order']['volume']
            print(f"Accumulated weight: {accumulated_weight}, volume: {accumulated_volume}")

        # Check if any dispatch criteria is met: weight, volume, or time
        if (accumulated_weight >= max_weight or 
            accumulated_volume >= max_volume or 
            datetime.now().time() >= dispatch_time) and order_buffer:
            
            print("Threshold met. Dispatching orders...")

            # Update the order status to "ready_for_dispatch"
            ready_orders = update_order_status(order_buffer)

            # Create a DataFrame for the orders if the buffer is not empty
            if ready_orders:
                df = spark.createDataFrame(ready_orders)

                # Write the orders to the "ready_for_dispatch" Delta table
                write_to_delta(df, delta_table_path_ready_for_dispatch)

                # # Send the batch of orders to the route optimizer (Routific)
                # if send_to_route_optimizer(ready_orders):
                #     print("Orders successfully sent to route optimizer.")

            # Clear buffer and reset accumulators after dispatch
            order_buffer = []
            accumulated_weight = 0
            accumulated_volume = 0

        else:
            print(f"Threshold not met yet. Weight: {accumulated_weight}, Volume: {accumulated_volume}")

        # Sleep for a short time before fetching new records (to avoid throttling)
        time.sleep(5)

# %%
dispatcher()
# Out:
# Starting dispatcher...
# Fetching records from Kinesis stream...
# Received order: {'client_id': 526061949432, 'location': {'address': 'Cuesta de Jacinta Aliaga, 885, Madrid, Spain', 'lat': 40.48663528941934, 'lon': -3.86801853646353}, 'order_id': '66b7045d-821e-43e4-a65a-8010c685090e', 'order': {'n_objects': 8, 'volume': 26.967033881885307, 'weight': 49.06647286407531}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:35:21'}
# Received order: {'client_id': 250134210269, 'location': {'address': 'Vial de Julie Santamaria, 11, Madrid, Spain', 'lat': 40.64034937337452, 'lon': -3.6961708148562606}, 'order_id': '3e0379b8-ffd0-461f-8b9a-df7e4fcdfd4c', 'order': {'n_objects': 8, 'volume': 92.1583121744296, 'weight': 31.08281969586028}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:35:36'}
# Received order: {'client_id': 563599983792, 'location': {'address': 'Cuesta de María Morell, 43, Madrid, Spain', 'lat': 40.55202562462943, 'lon': -3.5678584538759948}, 'order_id': '472e454c-2fed-42b2-93dd-45114c0c88e9', 'order': {'n_objects': 7, 'volume': 59.07408292000412, 'weight': 12.205739218217145}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:35:59'}
# Received order: {'client_id': 354536861094, 'location': {'address': 'Urbanización Roque Pla, 1, Madrid, Spain', 'lat': 40.33994317304784, 'lon': -3.567872107694277}, 'order_id': '6c7ad2b9-00f4-47f3-abb3-1af2cfad379f', 'order': {'n_objects': 3, 'volume': 58.902510397761795, 'weight': 25.854065994052227}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:36:23'}
# Received order: {'client_id': 369955844465, 'location': {'address': 'Cuesta de Elpidio Caparrós, 38, Madrid, Spain', 'lat': 40.59024296757875, 'lon': -3.7139927570216593}, 'order_id': '63150586-9617-4310-9858-0e789b2a8137', 'order': {'n_objects': 4, 'volume': 18.391154605577967, 'weight': 46.33508279293447}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:36:45'}
# Received order: {'client_id': 797516337645, 'location': {'address': 'Vial Felix Castejón, 457, Madrid, Spain', 'lat': 40.390624097630585, 'lon': -3.7763569579284644}, 'order_id': '96e8fafd-39fe-47da-bd46-ebc0e807332e', 'order': {'n_objects': 2, 'volume': 21.31284843328644, 'weight': 39.28810304611136}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:03'}
# Received order: {'client_id': 213700093857, 'location': {'address': 'Callejón de Felicia Machado, 26, Madrid, Spain', 'lat': 40.46152654919263, 'lon': -3.87708688586951}, 'order_id': 'd628f417-a6d5-433b-93a6-6af40e38598b', 'order': {'n_objects': 4, 'volume': 19.969738226891767, 'weight': 35.918748224844215}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:34'}
# Received order: {'client_id': 166755402451, 'location': {'address': 'Vial de Reyes Amo, 55, Madrid, Spain', 'lat': 40.61742586376899, 'lon': -3.878285558115845}, 'order_id': 'a0dfa490-6664-4f37-989c-88bcfae6a22a', 'order': {'n_objects': 2, 'volume': 84.10971760106702, 'weight': 2.560354048206538}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:46'}
# Received order: {'client_id': 341290740405, 'location': {'address': 'Camino Saturnina Lucas, 27, Madrid, Spain', 'lat': 40.49834670694099, 'lon': -3.635046702181735}, 'order_id': 'bec4c6e5-5506-4c06-9c6d-f9bfbe9a2fdc', 'order': {'n_objects': 6, 'volume': 45.01979176155189, 'weight': 20.68268063321395}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:55'}
# Received order: {'client_id': 870451730638, 'location': {'address': 'Pasadizo de Osvaldo Pazos, 859, Madrid, Spain', 'lat': 40.4501900201047, 'lon': -3.7907892858086716}, 'order_id': 'af59f0c4-64a4-4a51-976f-94314a3fcacf', 'order': {'n_objects': 4, 'volume': 95.67263146960404, 'weight': 29.234062244257778}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:38:07'}
# Received order: {'client_id': 561149250899, 'location': {'address': 'Cañada Teresa Macias, 1, Madrid, Spain', 'lat': 40.41707676890065, 'lon': -3.7587302864757794}, 'order_id': 'af0e5f3a-5073-4e3c-b2a1-2fd15a9bce88', 'order': {'n_objects': 2, 'volume': 64.02082645851085, 'weight': 9.29616317110778}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:38:26'}
# Received order: {'client_id': 909460628042, 'location': {'address': 'Cañada de Martirio Barrena, 78, Madrid, Spain', 'lat': 40.532811482130825, 'lon': -3.6991864695446735}, 'order_id': 'fa0c83d2-de29-4e41-baf0-ca01275d44dc', 'order': {'n_objects': 7, 'volume': 75.22612697878323, 'weight': 32.810793745104235}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:38:47'}
# Received order: {'client_id': 586421146091, 'location': {'address': 'Avenida Victor Elorza, 556, Madrid, Spain', 'lat': 40.42735305727478, 'lon': -3.7202342496359058}, 'order_id': 'e1adce42-d3fa-4f3a-bddf-64eb82f92654', 'order': {'n_objects': 9, 'volume': 90.20014258877461, 'weight': 3.1862959613284803}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:39:03'}
# Received order: {'client_id': 357712483425, 'location': {'address': 'Callejón de Wálter Ropero, 85, Madrid, Spain', 'lat': 40.36896443619372, 'lon': -3.8277862518687993}, 'order_id': 'e0f6f618-ced5-469d-a52a-f60c83a4e884', 'order': {'n_objects': 6, 'volume': 81.07701607864165, 'weight': 33.14397349899392}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:39:17'}
# Received order: {'client_id': 810886242646, 'location': {'address': 'Calle de Camilo Peñalver, 8, Madrid, Spain', 'lat': 40.599872469113, 'lon': -3.660567589049306}, 'order_id': '00d45fb7-80f6-42ce-9b6d-3b9c1c5c8a7f', 'order': {'n_objects': 1, 'volume': 98.83145431873618, 'weight': 36.65431394979386}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:39:48'}
# Received order: {'client_id': 155799026787, 'location': {'address': 'Rambla Tania Sales, 72, Madrid, Spain', 'lat': 40.44401319287373, 'lon': -3.7200662194692673}, 'order_id': '8a66b1f2-b138-45ef-94be-117a90c26cee', 'order': {'n_objects': 4, 'volume': 58.141276398084045, 'weight': 42.42503255578852}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:39:59'}
# Received order: {'client_id': 853849632985, 'location': {'address': 'Paseo Ricarda Huertas, 48, Madrid, Spain', 'lat': 40.36576685449255, 'lon': -3.671994300664761}, 'order_id': 'e810a291-1636-47b7-85f3-5dc8d64b7f6e', 'order': {'n_objects': 8, 'volume': 88.44691645115923, 'weight': 21.18565938085318}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:40:28'}
# Received order: {'client_id': 243472922017, 'location': {'address': 'Pasadizo Ildefonso Avilés, 798, Madrid, Spain', 'lat': 40.53792656065415, 'lon': -3.5185555757992386}, 'order_id': '955c6d93-dd55-4cca-8ee9-072cc802adc0', 'order': {'n_objects': 7, 'volume': 36.00158429295542, 'weight': 8.255675779043164}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:40:36'}
# Received order: {'client_id': 868420843515, 'location': {'address': 'Urbanización de Anita Zabala, 6, Madrid, Spain', 'lat': 40.49530467350505, 'lon': -3.5757253227681756}, 'order_id': 'ab97ed14-b158-4dfe-972d-bcd95abf50ed', 'order': {'n_objects': 2, 'volume': 46.36440653200764, 'weight': 6.788005055358639}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:41:03'}
# Received order: {'client_id': 265584417360, 'location': {'address': 'Avenida Lalo Cañas, 80, Madrid, Spain', 'lat': 40.5861680943814, 'lon': -3.6909994106053157}, 'order_id': '2c7a7bb1-e19d-4fc8-9f3b-81102052d98c', 'order': {'n_objects': 8, 'volume': 48.07551319086984, 'weight': 12.788344552016826}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:41:11'}
# Received order: {'client_id': 815282762367, 'location': {'address': 'Ronda de Nayara Bustos, 77, Madrid, Spain', 'lat': 40.553739019889576, 'lon': -3.7421254838599465}, 'order_id': 'b7150bf7-282b-4748-8ae5-535b89eccea3', 'order': {'n_objects': 7, 'volume': 57.156420837970394, 'weight': 14.797451262009526}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:41:32'}
# Received order: {'client_id': 248058790456, 'location': {'address': 'Callejón Chus Rovira, 76, Madrid, Spain', 'lat': 40.62043330100851, 'lon': -3.823992223533753}, 'order_id': '5f42698f-b088-4973-bb78-51b10cf586b3', 'order': {'n_objects': 2, 'volume': 38.37449141092453, 'weight': 5.0816212915010945}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:41:55'}
# Received order: {'client_id': 474766170776, 'location': {'address': 'Cuesta de Miriam Gutierrez, 154, Madrid, Spain', 'lat': 40.634439687732815, 'lon': -3.596689736378434}, 'order_id': 'dd014e32-5b82-4937-9cad-bcadbbac5276', 'order': {'n_objects': 1, 'volume': 48.911655568229584, 'weight': 48.71703499852073}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:42:26'}
# Received order: {'client_id': 148762711815, 'location': {'address': 'Camino de Asdrubal Céspedes, 66, Madrid, Spain', 'lat': 40.405306370086706, 'lon': -3.7572705946784075}, 'order_id': '03ab2aa5-0832-4a25-96d5-1505312ce5fa', 'order': {'n_objects': 6, 'volume': 51.69516421761319, 'weight': 2.211408863801687}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:42:53'}
# Received order: {'client_id': 843320292595, 'location': {'address': 'Callejón Nydia Llorente, 65, Madrid, Spain', 'lat': 40.61447461509143, 'lon': -3.76668051128445}, 'order_id': 'b2f3208c-9962-41c0-84c0-96369ef2a9b0', 'order': {'n_objects': 7, 'volume': 12.772131978910622, 'weight': 1.1018987105406786}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:43:04'}
# Received order: {'client_id': 704907788874, 'location': {'address': 'Via de Evangelina Campos, 87, Madrid, Spain', 'lat': 40.32727309244859, 'lon': -3.5314592332064083}, 'order_id': '264058b5-863c-4495-9345-5d79ce56341a', 'order': {'n_objects': 7, 'volume': 11.951586563221465, 'weight': 4.253827927368721}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:43:19'}
# Received order: {'client_id': 489803447881, 'location': {'address': 'Avenida Toño Cuadrado, 22, Madrid, Spain', 'lat': 40.63464036620236, 'lon': -3.5453591421287434}, 'order_id': '68d9167a-d6a7-451d-8865-a5f91b8789da', 'order': {'n_objects': 6, 'volume': 90.38349184245017, 'weight': 42.80402861499066}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:43:36'}
# Received order: {'client_id': 987654193745, 'location': {'address': 'Paseo Amanda Nebot, 8, Madrid, Spain', 'lat': 40.61312351289696, 'lon': -3.815793736038313}, 'order_id': '7bd8c1c6-9051-46b5-b01b-1c048c44a925', 'order': {'n_objects': 1, 'volume': 11.325765794784909, 'weight': 42.06543544067437}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:43:44'}
# Received order: {'client_id': 531508439556, 'location': {'address': 'Avenida Salomé Chaparro, 874, Madrid, Spain', 'lat': 40.48045749921995, 'lon': -3.618795767197648}, 'order_id': 'a570210b-02cf-4445-9749-6ad34f3b1f57', 'order': {'n_objects': 1, 'volume': 55.21671467156635, 'weight': 44.7587340320704}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:44:03'}
# Received order: {'client_id': 447187230618, 'location': {'address': 'Paseo Nilo Mur, 79, Madrid, Spain', 'lat': 40.33791435736148, 'lon': -3.7816760833345735}, 'order_id': '363833be-3c28-40e4-8451-d3dc00e9ba29', 'order': {'n_objects': 6, 'volume': 17.660935146011408, 'weight': 43.437853011817765}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:44:12'}
# Received order: {'client_id': 170318668996, 'location': {'address': 'Pasaje Samu Estrada, 22, Madrid, Spain', 'lat': 40.50342265896141, 'lon': -3.750595112735727}, 'order_id': 'fd984b96-8b8d-46b9-aa85-ce869c3b8b65', 'order': {'n_objects': 9, 'volume': 24.095816323038083, 'weight': 22.1600773549298}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:44:42'}
# Received order: {'client_id': 588208633941, 'location': {'address': 'Camino Tamara Ropero, 699, Madrid, Spain', 'lat': 40.443727542578586, 'lon': -3.8576952799015736}, 'order_id': '4f5b1cd9-39aa-4bf2-9fd2-ac0a649bd6f8', 'order': {'n_objects': 2, 'volume': 82.55385046823723, 'weight': 2.755920580618745}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:45:00'}
# Received order: {'client_id': 298282210016, 'location': {'address': 'Via Narcisa Valencia, 78, Madrid, Spain', 'lat': 40.528903017484176, 'lon': -3.6009894219963803}, 'order_id': '95514026-bf47-4922-abeb-5056fd750c97', 'order': {'n_objects': 1, 'volume': 26.385004299134764, 'weight': 1.1972924656815178}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:45:29'}
# Received order: {'client_id': 110671084298, 'location': {'address': 'Plaza Humberto Carretero, 36, Madrid, Spain', 'lat': 40.458938017075575, 'lon': -3.7725868293476372}, 'order_id': '180143ad-c596-47b5-b9a2-c97768706350', 'order': {'n_objects': 2, 'volume': 21.81308690142721, 'weight': 10.44922658935794}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:45:43'}
# Received order: {'client_id': 673018421068, 'location': {'address': 'C. de Ignacio Prado, 39, Madrid, Spain', 'lat': 40.41634376917768, 'lon': -3.6806504629288996}, 'order_id': '5d43643f-66e7-44f8-93c6-5e05f825ec4e', 'order': {'n_objects': 9, 'volume': 26.072326130665306, 'weight': 34.09536584584099}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:46:13'}
# Received order: {'client_id': 433966970742, 'location': {'address': 'Urbanización de Samuel Puente, 548, Madrid, Spain', 'lat': 40.57459841204228, 'lon': -3.626963000870363}, 'order_id': '1f229e6c-f3b6-4ea0-a6c8-98c885b2c69c', 'order': {'n_objects': 1, 'volume': 9.669864926388362, 'weight': 39.82703165424336}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:46:34'}
# Received order: {'client_id': 271466186760, 'location': {'address': 'Rambla Guadalupe Carbó, 19, Madrid, Spain', 'lat': 40.34728864675328, 'lon': -3.8568171124641815}, 'order_id': '3f044921-4ae6-4929-8fe9-e808dbfcc0d5', 'order': {'n_objects': 1, 'volume': 38.311183142625964, 'weight': 26.280097219160613}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:47:01'}
# Received order: {'client_id': 435114180767, 'location': {'address': 'Plaza Jacobo Alcaraz, 521, Madrid, Spain', 'lat': 40.31442899256926, 'lon': -3.796072738386215}, 'order_id': '8bac7a96-e3df-48ad-8a22-635670466d2a', 'order': {'n_objects': 9, 'volume': 3.6953494710133903, 'weight': 41.29087366793875}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:47:24'}
# Received order: {'client_id': 132688218599, 'location': {'address': 'Ronda Édgar Rivero, 30, Madrid, Spain', 'lat': 40.47668756294698, 'lon': -3.832932955767357}, 'order_id': '03a415ec-2826-45ec-afab-be76c854f34f', 'order': {'n_objects': 3, 'volume': 65.30248920867813, 'weight': 3.172692914338372}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:47:43'}
# Received order: {'client_id': 700495952393, 'location': {'address': 'Vial de Benigna Campillo, 63, Madrid, Spain', 'lat': 40.38720628600415, 'lon': -3.6234625430744254}, 'order_id': 'e67888f8-6e84-44e2-98e8-314df3677e43', 'order': {'n_objects': 5, 'volume': 71.51535974778882, 'weight': 23.77466622517819}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:47:53'}
# Received order: {'client_id': 267523069506, 'location': {'address': 'Rambla Adalberto Valenzuela, 6, Madrid, Spain', 'lat': 40.39436941053156, 'lon': -3.732492460509751}, 'order_id': '37b5d0da-b156-4836-bd5e-ae97c61104b3', 'order': {'n_objects': 5, 'volume': 90.1503393915178, 'weight': 36.79494686894545}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:48:07'}
# Received order: {'client_id': 179853157001, 'location': {'address': 'Calle de Edelmira Coll, 54, Madrid, Spain', 'lat': 40.33588099640274, 'lon': -3.792987953700615}, 'order_id': 'd01d44a1-f3df-4d7c-bea7-1bf145c00fe8', 'order': {'n_objects': 2, 'volume': 56.28603795601669, 'weight': 43.50840601255941}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:48:33'}
# Received order: {'client_id': 417330489678, 'location': {'address': 'Glorieta Francisco Olmedo, 84, Madrid, Spain', 'lat': 40.64255413733616, 'lon': -3.546759065365581}, 'order_id': 'e917cbcb-390e-46b5-8f05-f05a1c114648', 'order': {'n_objects': 9, 'volume': 23.357886527743865, 'weight': 34.51343729524224}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:48:55'}
# Received order: {'client_id': 438378283036, 'location': {'address': 'Cañada Cirino Morell, 563, Madrid, Spain', 'lat': 40.41180026416199, 'lon': -3.7534260938420076}, 'order_id': '3c781425-a8c0-408a-8575-fbf749f9f3c0', 'order': {'n_objects': 9, 'volume': 32.4281405516953, 'weight': 48.66658980132209}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:49:03'}
# Received order: {'client_id': 682901595302, 'location': {'address': 'Cuesta Hernán Navas, 87, Madrid, Spain', 'lat': 40.538098451770836, 'lon': -3.675557147091091}, 'order_id': 'e4bbb4fe-903c-4d09-b655-b30a059bd248', 'order': {'n_objects': 7, 'volume': 85.93913205049196, 'weight': 43.103476354862686}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:49:11'}
# Received order: {'client_id': 255268325287, 'location': {'address': 'Urbanización Sandra Collado, 15, Madrid, Spain', 'lat': 40.57111208686216, 'lon': -3.539275296808617}, 'order_id': 'e1f71584-f986-40b0-bd01-671ad7cffa35', 'order': {'n_objects': 8, 'volume': 37.92920059654723, 'weight': 6.362533408923941}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:49:40'}
# Received order: {'client_id': 475922078767, 'location': {'address': 'Alameda de Isaura Carrión, 6, Madrid, Spain', 'lat': 40.4539747717357, 'lon': -3.7498699875099786}, 'order_id': '0961ff45-ffa0-40a7-bbc7-43256aafcd06', 'order': {'n_objects': 5, 'volume': 47.49920251118151, 'weight': 38.9649578655445}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:49:46'}
# Received order: {'client_id': 594684417251, 'location': {'address': 'Calle Eladio Molins, 95, Madrid, Spain', 'lat': 40.40874553974947, 'lon': -3.6239183466694307}, 'order_id': 'e25799b1-3128-4058-93e3-3d412c4d7043', 'order': {'n_objects': 5, 'volume': 88.59108760260844, 'weight': 21.544066275039903}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:50:09'}
# Received order: {'client_id': 489378533569, 'location': {'address': 'Plaza de Nilda Ropero, 74, Madrid, Spain', 'lat': 40.46552283167147, 'lon': -3.5723095846470603}, 'order_id': '6c1cb72c-8ea2-4b54-9832-51522caa35d0', 'order': {'n_objects': 4, 'volume': 5.70344215235055, 'weight': 16.356351316667066}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:50:35'}
# Received order: {'client_id': 416025591787, 'location': {'address': 'Pasadizo de Jenaro Guerrero, 51, Madrid, Spain', 'lat': 40.56568640446364, 'lon': -3.821851228661003}, 'order_id': '075a83b9-af4d-4ee9-843e-4413e3548dba', 'order': {'n_objects': 3, 'volume': 55.47577107280953, 'weight': 37.75615274109056}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:50:56'}
# Received order: {'client_id': 668300331949, 'location': {'address': 'Rambla de Elpidio Rocha, 9, Madrid, Spain', 'lat': 40.4356496362197, 'lon': -3.565457150240044}, 'order_id': 'dae83728-be34-421a-a44c-aac669e452ce', 'order': {'n_objects': 2, 'volume': 4.9096429129658254, 'weight': 21.388407136068704}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:51:08'}
# Received order: {'client_id': 856018545873, 'location': {'address': 'Cañada de Marcio Carnero, 79, Madrid, Spain', 'lat': 40.35821531219914, 'lon': -3.6753288952797627}, 'order_id': '2890bc4b-4ceb-42f8-ba17-863a940345f7', 'order': {'n_objects': 1, 'volume': 50.48311775575571, 'weight': 1.9548611462688756}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:51:27'}
# Received order: {'client_id': 406473341630, 'location': {'address': 'Cañada de Eutropio Camino, 376, Madrid, Spain', 'lat': 40.40430019915404, 'lon': -3.855815019007718}, 'order_id': '2731d0c1-02bb-429f-8a0e-b1402c3d0b87', 'order': {'n_objects': 3, 'volume': 75.23520347954471, 'weight': 48.6038055496367}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:51:39'}
# Received order: {'client_id': 516698406412, 'location': {'address': 'Alameda Quique Arco, 5, Madrid, Spain', 'lat': 40.4594515047043, 'lon': -3.59009389405572}, 'order_id': 'a7d05479-e460-44f8-900a-15e29c57e84e', 'order': {'n_objects': 9, 'volume': 22.53268264867531, 'weight': 30.668254567576852}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:51:56'}
# Received order: {'client_id': 995294021271, 'location': {'address': 'C. de Florencia Blanes, 58, Madrid, Spain', 'lat': 40.53859464127286, 'lon': -3.876403921502755}, 'order_id': '3858b19a-0fc5-4149-881e-eca4677a5482', 'order': {'n_objects': 8, 'volume': 81.47479618978244, 'weight': 35.792190390536994}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:52:03'}
# Received order: {'client_id': 943814724309, 'location': {'address': 'Vial de Nieves Corominas, 50, Madrid, Spain', 'lat': 40.424422612282996, 'lon': -3.762166275785712}, 'order_id': 'b9cf9fef-8c3f-4ff1-9e03-928c9879fe32', 'order': {'n_objects': 5, 'volume': 70.88779119217752, 'weight': 39.76579929286953}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:52:34'}
# Received order: {'client_id': 898297137031, 'location': {'address': 'Rambla de Amaro Valcárcel, 2, Madrid, Spain', 'lat': 40.47589779908136, 'lon': -3.8672160375047593}, 'order_id': '8bb9df38-2cd9-479d-8959-b64f55c86239', 'order': {'n_objects': 4, 'volume': 61.36696894196049, 'weight': 34.27374450096101}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:52:48'}
# Received order: {'client_id': 179125392295, 'location': {'address': 'Rambla Lupe Valera, 37, Madrid, Spain', 'lat': 40.462838550534045, 'lon': -3.771960831969494}, 'order_id': 'f6108ea4-500b-4da4-a5f6-a2f9bc345ca3', 'order': {'n_objects': 3, 'volume': 78.94246754627795, 'weight': 34.12633650498263}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:53:12'}
# Received order: {'client_id': 438139427809, 'location': {'address': 'Paseo de Juan Valls, 5, Madrid, Spain', 'lat': 40.493312093561855, 'lon': -3.6203864466101994}, 'order_id': '3bda51cb-3d28-4383-89b7-9fba33ea0fa0', 'order': {'n_objects': 3, 'volume': 50.086065244440746, 'weight': 33.95528741227297}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:53:38'}
# Received order: {'client_id': 182702783421, 'location': {'address': 'Camino Gema Valera, 20, Madrid, Spain', 'lat': 40.5038611395722, 'lon': -3.8019274576413444}, 'order_id': '81ea85b6-6de2-44d9-a997-42c50a6950e6', 'order': {'n_objects': 4, 'volume': 53.33106838516303, 'weight': 36.49985772209409}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:53:46'}
# Received order: {'client_id': 889778489558, 'location': {'address': 'Pasaje Che Verdugo, 3, Madrid, Spain', 'lat': 40.394130454703536, 'lon': -3.5916786187411116}, 'order_id': 'c29b789b-ee3d-4688-9183-0a0b18c67d3d', 'order': {'n_objects': 9, 'volume': 86.54162410450594, 'weight': 10.647100046961288}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:54:07'}
# Received order: {'client_id': 828964776782, 'location': {'address': 'Vial de José Lillo, 71, Madrid, Spain', 'lat': 40.63263696611558, 'lon': -3.596139086407358}, 'order_id': '05fd9953-aa99-436e-9af0-1f3778bb7092', 'order': {'n_objects': 8, 'volume': 82.28752076462192, 'weight': 5.384591023434578}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:54:28'}
# Received order: {'client_id': 405906301930, 'location': {'address': 'C. Dionisia Perales, 427, Madrid, Spain', 'lat': 40.56320994102349, 'lon': -3.626844737298556}, 'order_id': '54b2aa46-06c0-4c99-ad73-968b62d458d5', 'order': {'n_objects': 5, 'volume': 98.21660033162402, 'weight': 33.01757879799674}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:54:46'}
# Received order: {'client_id': 920518181959, 'location': {'address': 'C. de Griselda Blázquez, 80, Madrid, Spain', 'lat': 40.58544627807028, 'lon': -3.8367800623176884}, 'order_id': 'c37ee86f-fa4b-48d1-81fc-03c0c33a9ce0', 'order': {'n_objects': 3, 'volume': 61.83867279436641, 'weight': 15.200186183826252}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:54:59'}
# Received order: {'client_id': 842200549557, 'location': {'address': 'Cuesta de Isidora Arrieta, 98, Madrid, Spain', 'lat': 40.471273790012624, 'lon': -3.8624131017135728}, 'order_id': 'b288f98a-6f1f-45bc-8ff9-998009affa2b', 'order': {'n_objects': 5, 'volume': 49.88067528093172, 'weight': 28.96262980984466}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:55:10'}
# Received order: {'client_id': 839470643244, 'location': {'address': 'Ronda de Fortunata Aliaga, 31, Madrid, Spain', 'lat': 40.37417802994538, 'lon': -3.6360766113221037}, 'order_id': '0d0a455b-500b-4099-88d0-46f502f4e94f', 'order': {'n_objects': 7, 'volume': 89.5111909018913, 'weight': 48.80169343061252}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:55:17'}
# Received order: {'client_id': 188522454974, 'location': {'address': 'Avenida de Sigfrido Seco, 192, Madrid, Spain', 'lat': 40.369932384992296, 'lon': -3.5789469352877563}, 'order_id': '1dfd5f33-ae07-4f89-877e-9d508ba7a8d2', 'order': {'n_objects': 6, 'volume': 58.93337409029118, 'weight': 36.18865198067866}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:55:32'}
# Received order: {'client_id': 809844441959, 'location': {'address': 'Callejón Juan Pablo Cordero, 63, Madrid, Spain', 'lat': 40.3272902131453, 'lon': -3.737507088764059}, 'order_id': 'b651ac0f-5a7e-455d-8135-09bac4b7ceda', 'order': {'n_objects': 8, 'volume': 45.053946767930086, 'weight': 8.967528958917532}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:55:58'}
# Received order: {'client_id': 204177400713, 'location': {'address': 'Urbanización de Elisa Pozuelo, 1, Madrid, Spain', 'lat': 40.48085612138041, 'lon': -3.54480770302532}, 'order_id': 'a6d7a4dd-a235-4a52-8398-c00117b66f31', 'order': {'n_objects': 5, 'volume': 70.24868088923624, 'weight': 32.07050008698717}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:56:15'}
# Received order: {'client_id': 124602457546, 'location': {'address': 'Cuesta Azahara Giner, 7, Madrid, Spain', 'lat': 40.413129933381, 'lon': -3.634113298726024}, 'order_id': 'f3b9e163-f1e7-4802-a444-32326622cf16', 'order': {'n_objects': 3, 'volume': 52.911375476799, 'weight': 5.0518930510173}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:56:44'}
# Received order: {'client_id': 702260269101, 'location': {'address': 'Pasadizo Claudia Piña, 60, Madrid, Spain', 'lat': 40.53121898551929, 'lon': -3.6002808738387526}, 'order_id': 'b3a65ade-4333-4b0e-b653-5963691be3be', 'order': {'n_objects': 6, 'volume': 45.285538958092985, 'weight': 15.467535642520104}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:57:02'}
# Received order: {'client_id': 669007300283, 'location': {'address': 'Acceso Cosme Carvajal, 79, Madrid, Spain', 'lat': 40.45126192249731, 'lon': -3.8175945758924645}, 'order_id': '8c7159c0-a3ce-43c8-ac26-f0ae50ce2bfe', 'order': {'n_objects': 1, 'volume': 39.97270563426724, 'weight': 1.6678251953152836}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:57:32'}
# Received order: {'client_id': 970158765634, 'location': {'address': 'Avenida de Arsenio Herrera, 27, Madrid, Spain', 'lat': 40.4506133702132, 'lon': -3.802552303439445}, 'order_id': '4921ab3a-39d9-4342-90b6-d9bfc86c3e67', 'order': {'n_objects': 9, 'volume': 49.20162708539074, 'weight': 17.16337626341302}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:57:59'}
# Received order: {'client_id': 781532341079, 'location': {'address': 'Calle Itziar Rebollo, 25, Madrid, Spain', 'lat': 40.3161402506421, 'lon': -3.6200962402013044}, 'order_id': '336c0044-27dc-4196-873d-696807d7f9c9', 'order': {'n_objects': 3, 'volume': 48.58256034431209, 'weight': 10.335222781247314}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:58:12'}
# Received order: {'client_id': 132175886345, 'location': {'address': 'Pasadizo de Manuelita Arellano, 60, Madrid, Spain', 'lat': 40.624455901201465, 'lon': -3.530208847300563}, 'order_id': '84468aed-0b2d-40a4-932c-d2c0ac6a370d', 'order': {'n_objects': 6, 'volume': 58.455677154545825, 'weight': 40.24880347706903}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:58:34'}
# Received order: {'client_id': 759473175318, 'location': {'address': 'Glorieta de Elisa Pereira, 9, Madrid, Spain', 'lat': 40.33613779857751, 'lon': -3.822081155100739}, 'order_id': 'fe228cae-37cf-4c8d-be89-71885c6a3bde', 'order': {'n_objects': 6, 'volume': 66.26029516981728, 'weight': 35.45692254386699}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:58:46'}
# Received order: {'client_id': 820545600332, 'location': {'address': 'Cañada de Flavio Gutiérrez, 19, Madrid, Spain', 'lat': 40.334789804449024, 'lon': -3.5230588759662194}, 'order_id': 'd8d69995-32c5-4274-b435-dc8ce7895fab', 'order': {'n_objects': 3, 'volume': 87.60589891156638, 'weight': 1.1041698830450246}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:59:03'}
# Received order: {'client_id': 486011547046, 'location': {'address': 'Urbanización Aarón Batalla, 33, Madrid, Spain', 'lat': 40.5973449450842, 'lon': -3.6904330900980264}, 'order_id': '7c845de5-e4e3-441d-b74a-276c889ea1f5', 'order': {'n_objects': 3, 'volume': 44.54747109758204, 'weight': 13.8360762069244}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:59:19'}
# Received order: {'client_id': 505404742590, 'location': {'address': 'Calle Camila Sabater, 9, Madrid, Spain', 'lat': 40.538633131292585, 'lon': -3.646916510004324}, 'order_id': '62b63bc8-8ad8-42bc-b917-e22333b3b67e', 'order': {'n_objects': 6, 'volume': 11.795121685496996, 'weight': 47.748155495189685}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:59:38'}
# Received order: {'client_id': 136164682580, 'location': {'address': 'Vial Isidora Lastra, 60, Madrid, Spain', 'lat': 40.36858125836891, 'lon': -3.7704425946298463}, 'order_id': 'a64b766b-9a16-466c-92f4-73a94e091f0c', 'order': {'n_objects': 9, 'volume': 77.38277847089915, 'weight': 13.426552977721903}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:00:00'}
# Received order: {'client_id': 268228016560, 'location': {'address': 'Calle de Jenaro Cuervo, 88, Madrid, Spain', 'lat': 40.448146659258086, 'lon': -3.6914551841737557}, 'order_id': '3b0e0670-3e5c-4ad6-9d6e-b4714661fba0', 'order': {'n_objects': 4, 'volume': 45.87706548502239, 'weight': 12.322419114305765}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:00:29'}
# Received order: {'client_id': 457462721412, 'location': {'address': 'Avenida de Mar Bosch, 50, Madrid, Spain', 'lat': 40.60344779118727, 'lon': -3.5600498169759063}, 'order_id': '4550b2cc-50a2-4d1c-bf31-975b441d05aa', 'order': {'n_objects': 7, 'volume': 55.82377599519409, 'weight': 24.916177791262662}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:00:43'}
# Received order: {'client_id': 728951846709, 'location': {'address': 'Pasaje de Nilda Suárez, 9, Madrid, Spain', 'lat': 40.412279732886894, 'lon': -3.827516324095969}, 'order_id': '698169e9-ea44-42b9-86c3-3c7e7bfa17dc', 'order': {'n_objects': 2, 'volume': 12.572618482516988, 'weight': 39.48099643673985}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:00:54'}
# Received order: {'client_id': 253853294828, 'location': {'address': 'Plaza de Fausto Sanabria, 79, Madrid, Spain', 'lat': 40.61754756762617, 'lon': -3.664493789489346}, 'order_id': '9e5ef55a-aea6-4245-bb3c-943bbc3c007c', 'order': {'n_objects': 1, 'volume': 77.28238223421761, 'weight': 8.53401724575715}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:01:02'}
# Received order: {'client_id': 966388710620, 'location': {'address': 'Pasadizo de Elvira Murcia, 22, Madrid, Spain', 'lat': 40.52362535729707, 'lon': -3.691248605006199}, 'order_id': 'a764f612-d877-477e-8798-ee45543e950f', 'order': {'n_objects': 8, 'volume': 41.26190538378671, 'weight': 38.356304695784374}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:01:21'}
# Received order: {'client_id': 409075305396, 'location': {'address': 'Avenida de Anastasio Fernandez, 44, Madrid, Spain', 'lat': 40.555017583068704, 'lon': -3.7730642144358133}, 'order_id': 'beebd249-b816-4a53-84f3-a9ff13ed13ac', 'order': {'n_objects': 2, 'volume': 74.95788963049382, 'weight': 36.37741354510942}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:01:35'}
# Received order: {'client_id': 471096860824, 'location': {'address': 'Calle de Ofelia Saldaña, 6, Madrid, Spain', 'lat': 40.33843238246461, 'lon': -3.607689302973302}, 'order_id': '7e50eaab-fe14-4dbb-b95e-5da4f95e1508', 'order': {'n_objects': 5, 'volume': 37.70053562115073, 'weight': 6.895784288927783}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:01:57'}
# Received order: {'client_id': 775303547021, 'location': {'address': 'Calle Obdulia Ariño, 83, Madrid, Spain', 'lat': 40.6177637979817, 'lon': -3.6139924931034284}, 'order_id': '5c7f9ec4-0bc4-4823-accb-f34fe0f47fbc', 'order': {'n_objects': 8, 'volume': 52.53551165735096, 'weight': 27.58451628601176}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:02:28'}
# Received order: {'client_id': 458175538176, 'location': {'address': 'Cañada Graciana Escrivá, 2, Madrid, Spain', 'lat': 40.397162167667, 'lon': -3.840729590075482}, 'order_id': '09469c97-b76f-4ed3-ab5d-3bb7f3b39ec0', 'order': {'n_objects': 1, 'volume': 85.52197758408548, 'weight': 22.356633679905396}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:02:42'}
# Received order: {'client_id': 358106990655, 'location': {'address': 'Pasaje de Carlos Ballesteros, 521, Madrid, Spain', 'lat': 40.31428421069598, 'lon': -3.8827473097100804}, 'order_id': '0d4f012c-2f20-4b22-b315-ca2a7b4c1ce7', 'order': {'n_objects': 8, 'volume': 5.1317800842907815, 'weight': 28.61467673355281}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:02:57'}
# Received order: {'client_id': 379769084554, 'location': {'address': 'Pasadizo de Eliseo Martínez, 11, Madrid, Spain', 'lat': 40.44343272940199, 'lon': -3.711089915340069}, 'order_id': 'ff5b518c-428f-4db4-8bcd-36552d5795c2', 'order': {'n_objects': 5, 'volume': 10.841813085718476, 'weight': 42.040730070095115}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:03:08'}
# Received order: {'client_id': 582587950017, 'location': {'address': 'Paseo de Amando Múñiz, 473, Madrid, Spain', 'lat': 40.33252932781965, 'lon': -3.7070133134531877}, 'order_id': 'f0306896-ab64-4334-91e6-a5264c86eadc', 'order': {'n_objects': 2, 'volume': 39.365093957651254, 'weight': 12.326367110182908}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:03:33'}
# Received order: {'client_id': 831883719833, 'location': {'address': 'Alameda Teresita Menendez, 39, Madrid, Spain', 'lat': 40.347251139733665, 'lon': -3.7455508418867067}, 'order_id': 'f2858179-7eb2-40ba-ad13-92ba60d57697', 'order': {'n_objects': 8, 'volume': 21.461581907741937, 'weight': 27.00401675501427}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:03:58'}
# Received order: {'client_id': 917107921063, 'location': {'address': 'Cuesta de Héctor Esteban, 95, Madrid, Spain', 'lat': 40.52907839445643, 'lon': -3.7470353683440996}, 'order_id': '786ae3dc-a674-491d-bce7-108744000c0a', 'order': {'n_objects': 7, 'volume': 4.041515200561144, 'weight': 28.502571955887344}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:04:15'}
# Received order: {'client_id': 665740872883, 'location': {'address': 'Glorieta de Mariano Duarte, 690, Madrid, Spain', 'lat': 40.58668798141048, 'lon': -3.6920519532642984}, 'order_id': '1601aec0-626e-4c3a-9ee1-a53c3260a2b7', 'order': {'n_objects': 1, 'volume': 5.6004154505513135, 'weight': 48.593879504776}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:04:37'}
# Received order: {'client_id': 846367198596, 'location': {'address': 'Rambla de David Cabañas, 557, Madrid, Spain', 'lat': 40.59261052718335, 'lon': -3.5759976640181366}, 'order_id': '007ae7ea-e0d2-46e2-9788-5cf380d7ec78', 'order': {'n_objects': 3, 'volume': 6.297166168123005, 'weight': 30.750272711210275}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:03'}
# Received order: {'client_id': 419575440090, 'location': {'address': 'Cañada de Anabel Niño, 91, Madrid, Spain', 'lat': 40.45246475585207, 'lon': -3.675922936930919}, 'order_id': '79029536-89fa-42e2-a469-fc8d4e8b3d2d', 'order': {'n_objects': 9, 'volume': 38.94763265149696, 'weight': 31.22658202979398}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:13'}
# Received order: {'client_id': 939812540939, 'location': {'address': 'Pasaje Plácido Escobar, 48, Madrid, Spain', 'lat': 40.589051858976795, 'lon': -3.704662400639491}, 'order_id': '3fd84b7a-33f7-44d1-9585-6f30f551a09e', 'order': {'n_objects': 5, 'volume': 55.25348023201058, 'weight': 13.526744791650128}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:20'}
# Received order: {'client_id': 947187205354, 'location': {'address': 'Cañada Wilfredo Jordán, 6, Madrid, Spain', 'lat': 40.39147021344994, 'lon': -3.597503375054044}, 'order_id': '8f2d9436-ddc5-4f13-be7f-3cb435730b8f', 'order': {'n_objects': 6, 'volume': 74.98658321963921, 'weight': 9.386389888778876}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:34'}
# Received order: {'client_id': 802337517867, 'location': {'address': 'Avenida de Dan Alcántara, 82, Madrid, Spain', 'lat': 40.39614150852301, 'lon': -3.7385290916577802}, 'order_id': 'c34d22e9-a004-4fe3-8765-191edbcac258', 'order': {'n_objects': 6, 'volume': 97.11612376206834, 'weight': 30.029401620979755}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:06:04'}
# Accumulated weight: 49.06647286407531, volume: 26.967033881885307
# Accumulated weight: 80.14929255993559, volume: 119.1253460563149
# Accumulated weight: 92.35503177815274, volume: 178.199428976319
# Accumulated weight: 118.20909777220496, volume: 237.1019393740808
# Accumulated weight: 164.5441805651394, volume: 255.4930939796588
# Accumulated weight: 203.83228361125077, volume: 276.8059424129452
# Accumulated weight: 239.751031836095, volume: 296.775680639837
# Accumulated weight: 242.31138588430153, volume: 380.885398240904
# Accumulated weight: 262.9940665175155, volume: 425.9051900024559
# Accumulated weight: 292.22812876177323, volume: 521.57782147206
# Accumulated weight: 301.524291932881, volume: 585.5986479305709
# Accumulated weight: 334.33508567798526, volume: 660.8247749093541
# Accumulated weight: 337.52138163931374, volume: 751.0249174981287
# Accumulated weight: 370.6653551383077, volume: 832.1019335767704
# Accumulated weight: 407.31966908810153, volume: 930.9333878955066
# Accumulated weight: 449.74470164389004, volume: 989.0746642935907
# Accumulated weight: 470.9303610247432, volume: 1077.5215807447498
# Accumulated weight: 479.18603680378635, volume: 1113.5231650377052
# Accumulated weight: 485.974041859145, volume: 1159.887571569713
# Accumulated weight: 498.76238641116186, volume: 1207.9630847605827
# Accumulated weight: 513.5598376731714, volume: 1265.1195055985531
# Accumulated weight: 518.6414589646724, volume: 1303.4939970094777
# Accumulated weight: 567.3584939631932, volume: 1352.4056525777073
# Accumulated weight: 569.5699028269948, volume: 1404.1008167953205
# Accumulated weight: 570.6718015375355, volume: 1416.8729487742312
# Accumulated weight: 574.9256294649043, volume: 1428.8245353374527
# Accumulated weight: 617.729658079895, volume: 1519.208027179903
# Accumulated weight: 659.7950935205694, volume: 1530.533792974688
# Accumulated weight: 704.5538275526397, volume: 1585.7505076462542
# Accumulated weight: 747.9916805644575, volume: 1603.4114427922655
# Accumulated weight: 770.1517579193874, volume: 1627.5072591153034
# Accumulated weight: 772.9076785000061, volume: 1710.0611095835407
# Accumulated weight: 774.1049709656876, volume: 1736.4461138826755
# Accumulated weight: 784.5541975550456, volume: 1758.2592007841026
# Accumulated weight: 818.6495634008866, volume: 1784.331526914768
# Accumulated weight: 858.4765950551299, volume: 1794.0013918411562
# Accumulated weight: 884.7566922742906, volume: 1832.3125749837823
# Accumulated weight: 926.0475659422293, volume: 1836.0079244547956
# Accumulated weight: 929.2202588565677, volume: 1901.3104136634736
# Accumulated weight: 952.9949250817459, volume: 1972.8257734112624
# Accumulated weight: 989.7898719506913, volume: 2062.9761128027803
# Accumulated weight: 1033.2982779632507, volume: 2119.262150758797
# Accumulated weight: 1067.811715258493, volume: 2142.620037286541
# Accumulated weight: 1116.478305059815, volume: 2175.0481778382364
# Accumulated weight: 1159.5817814146778, volume: 2260.9873098887283
# Accumulated weight: 1165.9443148236019, volume: 2298.9165104852755
# Accumulated weight: 1204.9092726891463, volume: 2346.415712996457
# Accumulated weight: 1226.4533389641863, volume: 2435.006800599065
# Accumulated weight: 1242.8096902808534, volume: 2440.7102427514155
# Accumulated weight: 1280.565843021944, volume: 2496.186013824225
# Accumulated weight: 1301.9542501580127, volume: 2501.095656737191
# Accumulated weight: 1303.9091113042816, volume: 2551.5787744929466
# Accumulated weight: 1352.5129168539183, volume: 2626.8139779724916
# Accumulated weight: 1383.1811714214953, volume: 2649.346660621167
# Accumulated weight: 1418.9733618120322, volume: 2730.8214568109493
# Accumulated weight: 1458.7391611049018, volume: 2801.709248003127
# Accumulated weight: 1493.0129056058627, volume: 2863.0762169450873
# Accumulated weight: 1527.1392421108453, volume: 2942.018684491365
# Accumulated weight: 1561.0945295231184, volume: 2992.104749735806
# Accumulated weight: 1597.5943872452124, volume: 3045.435818120969
# Accumulated weight: 1608.2414872921736, volume: 3131.977442225475
# Accumulated weight: 1613.626078315608, volume: 3214.264962990097
# Accumulated weight: 1646.6436571136048, volume: 3312.4815633217213
# Accumulated weight: 1661.843843297431, volume: 3374.320236116088
# Accumulated weight: 1690.8064731072757, volume: 3424.20091139702
# Accumulated weight: 1739.608166537888, volume: 3513.7121022989113
# Accumulated weight: 1775.7968185185669, volume: 3572.6454763892025
# Accumulated weight: 1784.7643474774843, volume: 3617.6994231571325
# Accumulated weight: 1816.8348475644714, volume: 3687.948104046369
# Accumulated weight: 1821.8867406154886, volume: 3740.859479523168
# Accumulated weight: 1837.3542762580087, volume: 3786.145018481261
# Accumulated weight: 1839.022101453324, volume: 3826.1177241155283
# Accumulated weight: 1856.185477716737, volume: 3875.319351200919
# Accumulated weight: 1866.5207004979843, volume: 3923.901911545231
# Accumulated weight: 1906.7695039750533, volume: 3982.357588699777
# Accumulated weight: 1942.2264265189203, volume: 4048.617883869594
# Accumulated weight: 1943.3305964019653, volume: 4136.2237827811605
# Accumulated weight: 1957.1666726088897, volume: 4180.771253878743
# Accumulated weight: 2004.9148281040793, volume: 4192.56637556424
# Accumulated weight: 2018.3413810818013, volume: 4269.949154035139
# Accumulated weight: 2030.663800196107, volume: 4315.826219520161
# Accumulated weight: 2055.5799779873696, volume: 4371.649995515356
# Accumulated weight: 2095.0609744241096, volume: 4384.222613997873
# Accumulated weight: 2103.594991669867, volume: 4461.504996232091
# Accumulated weight: 2141.951296365651, volume: 4502.766901615878
# Accumulated weight: 2178.3287099107606, volume: 4577.724791246372
# Accumulated weight: 2185.2244941996883, volume: 4615.425326867523
# Accumulated weight: 2212.8090104857, volume: 4667.960838524874
# Accumulated weight: 2235.1656441656055, volume: 4753.482816108959
# Accumulated weight: 2263.780320899158, volume: 4758.61459619325
# Accumulated weight: 2305.821050969253, volume: 4769.456409278968
# Accumulated weight: 2318.147418079436, volume: 4808.821503236619
# Accumulated weight: 2345.1514348344504, volume: 4830.2830851443605
# Accumulated weight: 2373.654006790338, volume: 4834.324600344921
# Accumulated weight: 2422.247886295114, volume: 4839.925015795473
# Accumulated weight: 2452.998159006324, volume: 4846.222181963596
# Accumulated weight: 2484.224741036118, volume: 4885.169814615093
# Accumulated weight: 2497.751485827768, volume: 4940.4232948471035
# Accumulated weight: 2507.137875716547, volume: 5015.409878066743
# Accumulated weight: 2537.1672773375267, volume: 5112.526001828811
# Threshold met. Dispatching orders...
# 24/09/30 20:28:18 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 24/09/30 20:28:26 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 24/09/30 20:28:30 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Written 100 records to Delta table.
# Fetching records from Kinesis stream...
# Received order: {'client_id': 526061949432, 'location': {'address': 'Cuesta de Jacinta Aliaga, 885, Madrid, Spain', 'lat': 40.48663528941934, 'lon': -3.86801853646353}, 'order_id': '66b7045d-821e-43e4-a65a-8010c685090e', 'order': {'n_objects': 8, 'volume': 26.967033881885307, 'weight': 49.06647286407531}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:35:21'}
# Received order: {'client_id': 250134210269, 'location': {'address': 'Vial de Julie Santamaria, 11, Madrid, Spain', 'lat': 40.64034937337452, 'lon': -3.6961708148562606}, 'order_id': '3e0379b8-ffd0-461f-8b9a-df7e4fcdfd4c', 'order': {'n_objects': 8, 'volume': 92.1583121744296, 'weight': 31.08281969586028}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:35:36'}
# Received order: {'client_id': 563599983792, 'location': {'address': 'Cuesta de María Morell, 43, Madrid, Spain', 'lat': 40.55202562462943, 'lon': -3.5678584538759948}, 'order_id': '472e454c-2fed-42b2-93dd-45114c0c88e9', 'order': {'n_objects': 7, 'volume': 59.07408292000412, 'weight': 12.205739218217145}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:35:59'}
# Received order: {'client_id': 354536861094, 'location': {'address': 'Urbanización Roque Pla, 1, Madrid, Spain', 'lat': 40.33994317304784, 'lon': -3.567872107694277}, 'order_id': '6c7ad2b9-00f4-47f3-abb3-1af2cfad379f', 'order': {'n_objects': 3, 'volume': 58.902510397761795, 'weight': 25.854065994052227}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:36:23'}
# Received order: {'client_id': 369955844465, 'location': {'address': 'Cuesta de Elpidio Caparrós, 38, Madrid, Spain', 'lat': 40.59024296757875, 'lon': -3.7139927570216593}, 'order_id': '63150586-9617-4310-9858-0e789b2a8137', 'order': {'n_objects': 4, 'volume': 18.391154605577967, 'weight': 46.33508279293447}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:36:45'}
# Received order: {'client_id': 797516337645, 'location': {'address': 'Vial Felix Castejón, 457, Madrid, Spain', 'lat': 40.390624097630585, 'lon': -3.7763569579284644}, 'order_id': '96e8fafd-39fe-47da-bd46-ebc0e807332e', 'order': {'n_objects': 2, 'volume': 21.31284843328644, 'weight': 39.28810304611136}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:03'}
# Received order: {'client_id': 213700093857, 'location': {'address': 'Callejón de Felicia Machado, 26, Madrid, Spain', 'lat': 40.46152654919263, 'lon': -3.87708688586951}, 'order_id': 'd628f417-a6d5-433b-93a6-6af40e38598b', 'order': {'n_objects': 4, 'volume': 19.969738226891767, 'weight': 35.918748224844215}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:34'}
# Received order: {'client_id': 166755402451, 'location': {'address': 'Vial de Reyes Amo, 55, Madrid, Spain', 'lat': 40.61742586376899, 'lon': -3.878285558115845}, 'order_id': 'a0dfa490-6664-4f37-989c-88bcfae6a22a', 'order': {'n_objects': 2, 'volume': 84.10971760106702, 'weight': 2.560354048206538}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:46'}
# Received order: {'client_id': 341290740405, 'location': {'address': 'Camino Saturnina Lucas, 27, Madrid, Spain', 'lat': 40.49834670694099, 'lon': -3.635046702181735}, 'order_id': 'bec4c6e5-5506-4c06-9c6d-f9bfbe9a2fdc', 'order': {'n_objects': 6, 'volume': 45.01979176155189, 'weight': 20.68268063321395}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:37:55'}
# Received order: {'client_id': 870451730638, 'location': {'address': 'Pasadizo de Osvaldo Pazos, 859, Madrid, Spain', 'lat': 40.4501900201047, 'lon': -3.7907892858086716}, 'order_id': 'af59f0c4-64a4-4a51-976f-94314a3fcacf', 'order': {'n_objects': 4, 'volume': 95.67263146960404, 'weight': 29.234062244257778}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:38:07'}
# Received order: {'client_id': 561149250899, 'location': {'address': 'Cañada Teresa Macias, 1, Madrid, Spain', 'lat': 40.41707676890065, 'lon': -3.7587302864757794}, 'order_id': 'af0e5f3a-5073-4e3c-b2a1-2fd15a9bce88', 'order': {'n_objects': 2, 'volume': 64.02082645851085, 'weight': 9.29616317110778}, 'status': 'in_progress', 'timestamp': '2024-09-29 20:38:26'}
# ...
# Received order: {'client_id': 471096860824, 'location': {'address': 'Calle de Ofelia Saldaña, 6, Madrid, Spain', 'lat': 40.33843238246461, 'lon': -3.607689302973302}, 'order_id': '7e50eaab-fe14-4dbb-b95e-5da4f95e1508', 'order': {'n_objects': 5, 'volume': 37.70053562115073, 'weight': 6.895784288927783}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:01:57'}
# Received order: {'client_id': 775303547021, 'location': {'address': 'Calle Obdulia Ariño, 83, Madrid, Spain', 'lat': 40.6177637979817, 'lon': -3.6139924931034284}, 'order_id': '5c7f9ec4-0bc4-4823-accb-f34fe0f47fbc', 'order': {'n_objects': 8, 'volume': 52.53551165735096, 'weight': 27.58451628601176}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:02:28'}
# Received order: {'client_id': 458175538176, 'location': {'address': 'Cañada Graciana Escrivá, 2, Madrid, Spain', 'lat': 40.397162167667, 'lon': -3.840729590075482}, 'order_id': '09469c97-b76f-4ed3-ab5d-3bb7f3b39ec0', 'order': {'n_objects': 1, 'volume': 85.52197758408548, 'weight': 22.356633679905396}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:02:42'}
# Received order: {'client_id': 358106990655, 'location': {'address': 'Pasaje de Carlos Ballesteros, 521, Madrid, Spain', 'lat': 40.31428421069598, 'lon': -3.8827473097100804}, 'order_id': '0d4f012c-2f20-4b22-b315-ca2a7b4c1ce7', 'order': {'n_objects': 8, 'volume': 5.1317800842907815, 'weight': 28.61467673355281}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:02:57'}
# Received order: {'client_id': 379769084554, 'location': {'address': 'Pasadizo de Eliseo Martínez, 11, Madrid, Spain', 'lat': 40.44343272940199, 'lon': -3.711089915340069}, 'order_id': 'ff5b518c-428f-4db4-8bcd-36552d5795c2', 'order': {'n_objects': 5, 'volume': 10.841813085718476, 'weight': 42.040730070095115}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:03:08'}
# Received order: {'client_id': 582587950017, 'location': {'address': 'Paseo de Amando Múñiz, 473, Madrid, Spain', 'lat': 40.33252932781965, 'lon': -3.7070133134531877}, 'order_id': 'f0306896-ab64-4334-91e6-a5264c86eadc', 'order': {'n_objects': 2, 'volume': 39.365093957651254, 'weight': 12.326367110182908}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:03:33'}
# Received order: {'client_id': 831883719833, 'location': {'address': 'Alameda Teresita Menendez, 39, Madrid, Spain', 'lat': 40.347251139733665, 'lon': -3.7455508418867067}, 'order_id': 'f2858179-7eb2-40ba-ad13-92ba60d57697', 'order': {'n_objects': 8, 'volume': 21.461581907741937, 'weight': 27.00401675501427}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:03:58'}
# Received order: {'client_id': 917107921063, 'location': {'address': 'Cuesta de Héctor Esteban, 95, Madrid, Spain', 'lat': 40.52907839445643, 'lon': -3.7470353683440996}, 'order_id': '786ae3dc-a674-491d-bce7-108744000c0a', 'order': {'n_objects': 7, 'volume': 4.041515200561144, 'weight': 28.502571955887344}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:04:15'}
# Received order: {'client_id': 665740872883, 'location': {'address': 'Glorieta de Mariano Duarte, 690, Madrid, Spain', 'lat': 40.58668798141048, 'lon': -3.6920519532642984}, 'order_id': '1601aec0-626e-4c3a-9ee1-a53c3260a2b7', 'order': {'n_objects': 1, 'volume': 5.6004154505513135, 'weight': 48.593879504776}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:04:37'}
# Received order: {'client_id': 846367198596, 'location': {'address': 'Rambla de David Cabañas, 557, Madrid, Spain', 'lat': 40.59261052718335, 'lon': -3.5759976640181366}, 'order_id': '007ae7ea-e0d2-46e2-9788-5cf380d7ec78', 'order': {'n_objects': 3, 'volume': 6.297166168123005, 'weight': 30.750272711210275}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:03'}
# Received order: {'client_id': 419575440090, 'location': {'address': 'Cañada de Anabel Niño, 91, Madrid, Spain', 'lat': 40.45246475585207, 'lon': -3.675922936930919}, 'order_id': '79029536-89fa-42e2-a469-fc8d4e8b3d2d', 'order': {'n_objects': 9, 'volume': 38.94763265149696, 'weight': 31.22658202979398}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:13'}
# Received order: {'client_id': 939812540939, 'location': {'address': 'Pasaje Plácido Escobar, 48, Madrid, Spain', 'lat': 40.589051858976795, 'lon': -3.704662400639491}, 'order_id': '3fd84b7a-33f7-44d1-9585-6f30f551a09e', 'order': {'n_objects': 5, 'volume': 55.25348023201058, 'weight': 13.526744791650128}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:20'}
# Received order: {'client_id': 947187205354, 'location': {'address': 'Cañada Wilfredo Jordán, 6, Madrid, Spain', 'lat': 40.39147021344994, 'lon': -3.597503375054044}, 'order_id': '8f2d9436-ddc5-4f13-be7f-3cb435730b8f', 'order': {'n_objects': 6, 'volume': 74.98658321963921, 'weight': 9.386389888778876}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:05:34'}
# Received order: {'client_id': 802337517867, 'location': {'address': 'Avenida de Dan Alcántara, 82, Madrid, Spain', 'lat': 40.39614150852301, 'lon': -3.7385290916577802}, 'order_id': 'c34d22e9-a004-4fe3-8765-191edbcac258', 'order': {'n_objects': 6, 'volume': 97.11612376206834, 'weight': 30.029401620979755}, 'status': 'in_progress', 'timestamp': '2024-09-29 21:06:04'}
# Accumulated weight: 49.06647286407531, volume: 26.967033881885307
# Accumulated weight: 80.14929255993559, volume: 119.1253460563149
# Accumulated weight: 92.35503177815274, volume: 178.199428976319
# Accumulated weight: 118.20909777220496, volume: 237.1019393740808
# Accumulated weight: 164.5441805651394, volume: 255.4930939796588
# Accumulated weight: 203.83228361125077, volume: 276.8059424129452
# Accumulated weight: 239.751031836095, volume: 296.775680639837
# Accumulated weight: 242.31138588430153, volume: 380.885398240904
# Accumulated weight: 262.9940665175155, volume: 425.9051900024559
# Accumulated weight: 292.22812876177323, volume: 521.57782147206
# Accumulated weight: 301.524291932881, volume: 585.5986479305709
# Accumulated weight: 334.33508567798526, volume: 660.8247749093541
# Accumulated weight: 337.52138163931374, volume: 751.0249174981287
# Accumulated weight: 370.6653551383077, volume: 832.1019335767704
# Accumulated weight: 407.31966908810153, volume: 930.9333878955066
# Accumulated weight: 449.74470164389004, volume: 989.0746642935907
# Accumulated weight: 470.9303610247432, volume: 1077.5215807447498
# Accumulated weight: 479.18603680378635, volume: 1113.5231650377052
# Accumulated weight: 485.974041859145, volume: 1159.887571569713
# Accumulated weight: 498.76238641116186, volume: 1207.9630847605827
# Accumulated weight: 513.5598376731714, volume: 1265.1195055985531
# Accumulated weight: 518.6414589646724, volume: 1303.4939970094777
# Accumulated weight: 567.3584939631932, volume: 1352.4056525777073
# Accumulated weight: 569.5699028269948, volume: 1404.1008167953205
# Accumulated weight: 570.6718015375355, volume: 1416.8729487742312
# Accumulated weight: 574.9256294649043, volume: 1428.8245353374527
# Accumulated weight: 617.729658079895, volume: 1519.208027179903
# Accumulated weight: 659.7950935205694, volume: 1530.533792974688
# Accumulated weight: 704.5538275526397, volume: 1585.7505076462542
# Accumulated weight: 747.9916805644575, volume: 1603.4114427922655
# Accumulated weight: 770.1517579193874, volume: 1627.5072591153034
# Accumulated weight: 772.9076785000061, volume: 1710.0611095835407
# Accumulated weight: 774.1049709656876, volume: 1736.4461138826755
# Accumulated weight: 784.5541975550456, volume: 1758.2592007841026
# Accumulated weight: 818.6495634008866, volume: 1784.331526914768
# Accumulated weight: 858.4765950551299, volume: 1794.0013918411562
# Accumulated weight: 884.7566922742906, volume: 1832.3125749837823
# Accumulated weight: 926.0475659422293, volume: 1836.0079244547956
# Accumulated weight: 929.2202588565677, volume: 1901.3104136634736
# Accumulated weight: 952.9949250817459, volume: 1972.8257734112624
# Accumulated weight: 989.7898719506913, volume: 2062.9761128027803
# Accumulated weight: 1033.2982779632507, volume: 2119.262150758797
# Accumulated weight: 1067.811715258493, volume: 2142.620037286541
# Accumulated weight: 1116.478305059815, volume: 2175.0481778382364
# Accumulated weight: 1159.5817814146778, volume: 2260.9873098887283
# Accumulated weight: 1165.9443148236019, volume: 2298.9165104852755
# Accumulated weight: 1204.9092726891463, volume: 2346.415712996457
# Accumulated weight: 1226.4533389641863, volume: 2435.006800599065
# Accumulated weight: 1242.8096902808534, volume: 2440.7102427514155
# Accumulated weight: 1280.565843021944, volume: 2496.186013824225
# Accumulated weight: 1301.9542501580127, volume: 2501.095656737191
# Accumulated weight: 1303.9091113042816, volume: 2551.5787744929466
# Accumulated weight: 1352.5129168539183, volume: 2626.8139779724916
# Accumulated weight: 1383.1811714214953, volume: 2649.346660621167
# Accumulated weight: 1418.9733618120322, volume: 2730.8214568109493
# Accumulated weight: 1458.7391611049018, volume: 2801.709248003127
# Accumulated weight: 1493.0129056058627, volume: 2863.0762169450873
# Accumulated weight: 1527.1392421108453, volume: 2942.018684491365
# Accumulated weight: 1561.0945295231184, volume: 2992.104749735806
# Accumulated weight: 1597.5943872452124, volume: 3045.435818120969
# Accumulated weight: 1608.2414872921736, volume: 3131.977442225475
# Accumulated weight: 1613.626078315608, volume: 3214.264962990097
# Accumulated weight: 1646.6436571136048, volume: 3312.4815633217213
# Accumulated weight: 1661.843843297431, volume: 3374.320236116088
# Accumulated weight: 1690.8064731072757, volume: 3424.20091139702
# Accumulated weight: 1739.608166537888, volume: 3513.7121022989113
# Accumulated weight: 1775.7968185185669, volume: 3572.6454763892025
# Accumulated weight: 1784.7643474774843, volume: 3617.6994231571325
# Accumulated weight: 1816.8348475644714, volume: 3687.948104046369
# Accumulated weight: 1821.8867406154886, volume: 3740.859479523168
# Accumulated weight: 1837.3542762580087, volume: 3786.145018481261
# Accumulated weight: 1839.022101453324, volume: 3826.1177241155283
# Accumulated weight: 1856.185477716737, volume: 3875.319351200919
# Accumulated weight: 1866.5207004979843, volume: 3923.901911545231
# Accumulated weight: 1906.7695039750533, volume: 3982.357588699777
# Accumulated weight: 1942.2264265189203, volume: 4048.617883869594
# Accumulated weight: 1943.3305964019653, volume: 4136.2237827811605
# Accumulated weight: 1957.1666726088897, volume: 4180.771253878743
# Accumulated weight: 2004.9148281040793, volume: 4192.56637556424
# Accumulated weight: 2018.3413810818013, volume: 4269.949154035139
# Accumulated weight: 2030.663800196107, volume: 4315.826219520161
# Accumulated weight: 2055.5799779873696, volume: 4371.649995515356
# Accumulated weight: 2095.0609744241096, volume: 4384.222613997873
# Accumulated weight: 2103.594991669867, volume: 4461.504996232091
# Accumulated weight: 2141.951296365651, volume: 4502.766901615878
# Accumulated weight: 2178.3287099107606, volume: 4577.724791246372
# Accumulated weight: 2185.2244941996883, volume: 4615.425326867523
# Accumulated weight: 2212.8090104857, volume: 4667.960838524874
# Accumulated weight: 2235.1656441656055, volume: 4753.482816108959
# Accumulated weight: 2263.780320899158, volume: 4758.61459619325
# Accumulated weight: 2305.821050969253, volume: 4769.456409278968
# Accumulated weight: 2318.147418079436, volume: 4808.821503236619
# Accumulated weight: 2345.1514348344504, volume: 4830.2830851443605
# Accumulated weight: 2373.654006790338, volume: 4834.324600344921
# Accumulated weight: 2422.247886295114, volume: 4839.925015795473
# Accumulated weight: 2452.998159006324, volume: 4846.222181963596
# Accumulated weight: 2484.224741036118, volume: 4885.169814615093
# Accumulated weight: 2497.751485827768, volume: 4940.4232948471035
# Accumulated weight: 2507.137875716547, volume: 5015.409878066743
# Accumulated weight: 2537.1672773375267, volume: 5112.526001828811
# Threshold met. Dispatching orders...
# 24/09/30 20:32:18 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/Users/borja/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/borja/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/borja/.pyenv/versions/3.11.8/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dispatcher()
#
# Cell In[7], line 40, in dispatcher()
#      37     df = spark.createDataFrame(ready_orders)
#      39     # Write the orders to the "ready_for_dispatch" Delta table
# ---> 40     write_to_delta(df, delta_table_path_ready_for_dispatch)
#      42     # # Send the batch of orders to the route optimizer (Routific)
#      43     # if send_to_route_optimizer(ready_orders):
#      44     #     print("Orders successfully sent to route optimizer.")
#      45
#      46 # Clear buffer and reset accumulators after dispatch
#      47 order_buffer = []
#
# Cell In[4], line 9, in write_to_delta(df, delta_table_path)
#       8 def write_to_delta(df, delta_table_path):
# ----> 9     df.write.format("delta").mode("append").save(delta_table_path)
#      10     print(f"Written {df.count()} records to Delta table.")
#
# File ~/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/pyspark/sql/readwriter.py:1398, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#    1396     self._jwrite.save()
#    1397 else:
# -> 1398     self._jwrite.save(path)
#
# File ~/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
