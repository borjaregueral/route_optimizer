# %%
import boto3
import json
import time
from dotenv import load_dotenv
from datetime import datetime
import os
from delta.tables import DeltaTable

# Load environment variables from .env file
load_dotenv()

# Initialize AWS credentials from the .env file
AWS_ACCESS_KEY_ID = os.getenv('AWS_ACCESS_KEY_ID')
AWS_SECRET_ACCESS_KEY = os.getenv('AWS_SECRET_ACCESS_KEY')
AWS_SESSION_TOKEN = os.getenv('AWS_SESSION_TOKEN')
AWS_REGION = os.getenv('AWS_REGION')
ROUTIFIC_TOKEN = os.getenv('ROUTIFIC_TOKEN')

# %%
# Initialize boto3 client for Kinesis with your credentials
kinesis_client = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    aws_session_token=AWS_SESSION_TOKEN,
    region_name=AWS_REGION
)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("DeltaTableReader") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0,org.apache.hadoop:hadoop-aws:3.3.1") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# Path to the Delta table in S3
delta_table_path = "s3a://orders-for-dispatch/ready_for_dispatch"

# %%
# Path to the Delta table in S3
delta_table_path = 's3a://orders-for-dispatch/dispatching'

# %%
# Function to read records marked as ready for dispatch
def read_ready_for_dispatch_orders():
    # Load the Delta table
    delta_table = DeltaTable.forPath(spark, delta_table_path)
    
    # Query the Delta table to fetch only the records marked as READY_FOR_DISPATCH
    df = delta_table.toDF().filter("status = 'READY_FOR_DISPATCH'")
    
    # Return the DataFrame
    return df

# %%
# Fetch the ready-for-dispatch orders
ready_orders_df = read_ready_for_dispatch_orders()

# Convert the DataFrame to a list of Row objects
ready_orders = ready_orders_df.collect()
# Out:
# 24/10/02 04:05:01 WARN DeltaLog: Change in the table id detected while updating snapshot.
# Previous snapshot = Snapshot(path=s3a://orders-for-dispatch/dispatching/_delta_log, version=83, metadata=Metadata(32e99d0b-4860-41b1-b62a-1b1d387224f7,null,null,Format(parquet,Map()),{"type":"struct","fields":[{"name":"order_id","type":"string","nullable":true,"metadata":{}},{"name":"customer_id","type":"string","nullable":true,"metadata":{}},{"name":"total_weight","type":"double","nullable":true,"metadata":{}},{"name":"total_volume","type":"double","nullable":true,"metadata":{}},{"name":"total_price","type":"double","nullable":true,"metadata":{}},{"name":"order_timestamp","type":"timestamp","nullable":true,"metadata":{}},{"name":"status","type":"string","nullable":true,"metadata":{}},{"name":"lat","type":"double","nullable":true,"metadata":{}},{"name":"lon","type":"double","nullable":true,"metadata":{}},{"name":"served_customer_id","type":"string","nullable":true,"metadata":{}},{"name":"updated_finish_time","type":"timestamp","nullable":true,"metadata":{}}]},List(),Map(),Some(1727827304371)), logSegment=LogSegment(s3a://orders-for-dispatch/dispatching/_delta_log,83,WrappedArray(S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000081.json; isDirectory=false; length=3812; replication=1; blocksize=33554432; modification_time=1727834151000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=442aa746bb964556a1846dfca2898e9d versionId=null, S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000082.json; isDirectory=false; length=2662; replication=1; blocksize=33554432; modification_time=1727834203000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=f083356bae22d8c6e252523756926041 versionId=null, S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000083.json; isDirectory=false; length=2670; replication=1; blocksize=33554432; modification_time=1727834277000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=8aef65466c4bfa4aae9245d7b0573817 versionId=null),Some(PreloadedCheckpointProvider(WrappedArray(S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000080.checkpoint.parquet; isDirectory=false; length=35798; replication=1; blocksize=33554432; modification_time=1727834075000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=7db2ecf8b086e1aef01ad3e59d744b55 versionId=null),Some(CheckpointMetaData(80,224,None,Some(35798),Some(20),Some(StructType(StructField(txn,StructType(StructField(appId,StringType,true),StructField(version,LongType,true),StructField(lastUpdated,LongType,true)),true),StructField(add,StructType(StructField(path,StringType,true),StructField(partitionValues,MapType(StringType,StringType,true),true),StructField(size,LongType,true),StructField(modificationTime,LongType,true),StructField(dataChange,BooleanType,true),StructField(tags,MapType(StringType,StringType,true),true),StructField(deletionVector,StructType(StructField(storageType,StringType,true),StructField(pathOrInlineDv,StringType,true),StructField(offset,IntegerType,true),StructField(sizeInBytes,IntegerType,true),StructField(cardinality,LongType,true),StructField(maxRowIndex,LongType,true)),true),StructField(stats,StringType,true)),true),StructField(remove,StructType(StructField(path,StringType,true),StructField(deletionTimestamp,LongType,true),StructField(dataChange,BooleanType,true),StructField(extendedFileMetadata,BooleanType,true),StructField(partitionValues,MapType(StringType,StringType,true),true),StructField(size,LongType,true),StructField(deletionVector,StructType(StructField(storageType,St ...
# New snapshot = Snapshot(path=s3a://orders-for-dispatch/dispatching/_delta_log, version=5, metadata=Metadata(6acff9f1-bb75-4bd2-bf60-fbba9b10eefb,null,null,Format(parquet,Map()),{"type":"struct","fields":[{"name":"order_id","type":"string","nullable":true,"metadata":{}},{"name":"customer_id","type":"string","nullable":true,"metadata":{}},{"name":"total_weight","type":"double","nullable":true,"metadata":{}},{"name":"total_volume","type":"double","nullable":true,"metadata":{}},{"name":"total_price","type":"double","nullable":true,"metadata":{}},{"name":"order_timestamp","type":"timestamp","nullable":true,"metadata":{}},{"name":"status","type":"string","nullable":true,"metadata":{}},{"name":"lat","type":"double","nullable":true,"metadata":{}},{"name":"lon","type":"double","nullable":true,"metadata":{}}]},List(),Map(),Some(1727834510168)), logSegment=LogSegment(s3a://orders-for-dispatch/dispatching/_delta_log,5,WrappedArray(S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000000.json; isDirectory=false; length=2445; replication=1; blocksize=33554432; modification_time=1727834523000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=ed68207523e4d98759ab2a2f206aa744 versionId=null, S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000001.json; isDirectory=false; length=1465; replication=1; blocksize=33554432; modification_time=1727834555000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=bfaeec2659585c5fe63baf32daab33fe versionId=null, S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000002.json; isDirectory=false; length=1459; replication=1; blocksize=33554432; modification_time=1727834587000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=eda7a6f42530557c24c91b8788f5de26 versionId=null, S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000003.json; isDirectory=false; length=1469; replication=1; blocksize=33554432; modification_time=1727834629000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=3a07bea1fad3af2bd3231a760a8757fd versionId=null, S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000004.json; isDirectory=false; length=1467; replication=1; blocksize=33554432; modification_time=1727834667000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=2800764869ff9a834f270f2876aa32ab versionId=null, S3AFileStatus{path=s3a://orders-for-dispatch/dispatching/_delta_log/00000000000000000005.json; isDirectory=false; length=1469; replication=1; blocksize=33554432; modification_time=1727834691000; access_time=0; owner=borja; group=borja; permission=rw-rw-rw-; isSymlink=false; hasAcl=false; isEncrypted=true; isErasureCoded=false} isEmptyDirectory=FALSE eTag=f5cc5e23d24d6e4f8e495bb75cfedb92 versionId=null),None,1727834691000), checksumOpt=None).

# %%
ready_orders_df.show()
# Out:
# [Stage 20:>                                                         (0 + 2) / 2]
# +--------------------+--------------------+-----------------+------------------+------------------+-------------------+------------------+------------------+-------------------+
# |            order_id|         customer_id|     total_weight|      total_volume|       total_price|    order_timestamp|            status|               lat|                lon|
# +--------------------+--------------------+-----------------+------------------+------------------+-------------------+------------------+------------------+-------------------+
# |140680f5-cbf9-405...|cus-ba8d32e6-6f9c...|82.73160870030328| 318.9174240318443|412.70773183574084|2024-10-02 04:01:42|READY_FOR_DISPATCH|  40.5202115180548|-3.8638075430981003|
# |9b442566-8a8b-408...|cus-012169ba-74fe...|48.73753836832661|242.98560297383696| 572.0745375784338|2024-10-02 04:04:22|READY_FOR_DISPATCH| 40.41326882171988|-3.7854324815045137|
# |6ba61fa1-8590-4e4...|cus-e54fd919-0cd3...|43.53990041187081|139.95677803342312|420.68691285213123|2024-10-02 04:03:43|READY_FOR_DISPATCH| 40.56735698592657|-3.7339000542917575|
# |ae7715ce-7714-4d2...|cus-99e1c03c-9e4d...|48.12950760579068|   460.40128508892| 928.9953000140409|2024-10-02 04:03:00|READY_FOR_DISPATCH| 40.55352027399454| -3.846850240184429|
# |0562e23b-c8c5-41d...|cus-4b7057d8-c3dd...|46.74087426850831|392.79371443806525|   312.49896608574|2024-10-02 04:04:56|READY_FOR_DISPATCH|40.570276017311635| -3.632292221828427|
# |b26faf91-8581-47c...|cus-bbf84676-a48e...|38.75207275621183| 270.4332401055019| 36.17281916219022|2024-10-02 04:02:29|READY_FOR_DISPATCH| 40.37381234111349|-3.6619045311504714|
# |64bd7522-0a7f-44e...|cus-5c6fc123-cf6a...|90.67317748547849|375.40339945429565|291.02050389950824|2024-10-02 04:04:45|READY_FOR_DISPATCH| 40.64060844221572|-3.7070802941843075|
# +--------------------+--------------------+-----------------+------------------+------------------+-------------------+------------------+------------------+-------------------+

# %%
import random
import numpy as np

# List of possible priorities
priorities = ["low", "regular", "high"]

# Function to write JSON with visits in the required format
def format_to_visits(data):
    if data is None:
        print("Data is None, cannot format visits.")
        return {}

    visits = {
        item['order_id']: {
            "location": {
                "name": item['customer_id'],  # Routific requires a 'name' field for each location
                "lat": round(item['lat'], 6),  # Latitude from your data
                "lng": round(item['lon'], 7)  # Longitude from your data (changed 'lon' to 'lng' for consistency with Routific API)
            },
            "start": "9:00",  # Default start time (customize if you have specific times)
            "end": "18:00",  # Default end time
            "duration": 5,  # Default duration (customize as needed)
            "load": {
                "weight": int(np.ceil(item['total_weight'])),  # Use the 'total_weight' from the row
                "volume": int(np.ceil(item['total_volume']))  # Use the 'total_volume' from the row
            },
            "priority": random.choice(priorities),  # Assign a random priority for each order
        } for item in data
    }
    return visits



# Step 3: Transform the orders into the Routific format
visits_for_routific = format_to_visits(ready_orders)

# Check the output to verify the visits are correctly formatted
print("Visits formatted for Routific API:")
print(json.dumps(visits_for_routific, indent=4))
# Out:
# Visits formatted for Routific API:
# {
#     "140680f5-cbf9-4056-922e-2ff935a078f2": {
#         "location": {
#             "name": "cus-ba8d32e6-6f9c-4ddb-a0a0-bdc936739fbb",
#             "lat": 40.520212,
#             "lng": -3.8638075
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 83,
#             "volume": 319
#         },
#         "priority": "high"
#     },
#     "9b442566-8a8b-4081-b6fd-87ff8cb1be2e": {
#         "location": {
#             "name": "cus-012169ba-74fe-44ad-b7f7-48923011499a",
#             "lat": 40.413269,
#             "lng": -3.7854325
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 49,
#             "volume": 243
#         },
#         "priority": "low"
#     },
#     "6ba61fa1-8590-4e43-a3d5-440268d80b52": {
#         "location": {
#             "name": "cus-e54fd919-0cd3-40e3-801b-3aa4f0015c6a",
#             "lat": 40.567357,
#             "lng": -3.7339001
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 44,
#             "volume": 140
#         },
#         "priority": "low"
#     },
#     "ae7715ce-7714-4d2e-8beb-6e4e69e3ca72": {
#         "location": {
#             "name": "cus-99e1c03c-9e4d-4a38-92b4-34819d8a1909",
#             "lat": 40.55352,
#             "lng": -3.8468502
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 49,
#             "volume": 461
#         },
#         "priority": "regular"
#     },
#     "0562e23b-c8c5-41d8-9312-e1e7afa0898d": {
#         "location": {
#             "name": "cus-4b7057d8-c3dd-4449-b4dc-5f4c15a4bdb6",
#             "lat": 40.570276,
#             "lng": -3.6322922
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 47,
#             "volume": 393
#         },
#         "priority": "high"
#     },
#     "b26faf91-8581-47c5-8a7a-bcab8ef664a9": {
#         "location": {
#             "name": "cus-bbf84676-a48e-4beb-8758-22a8bbcdbd03",
#             "lat": 40.373812,
#             "lng": -3.6619045
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 39,
#             "volume": 271
#         },
#         "priority": "regular"
#     },
#     "64bd7522-0a7f-44e0-a79f-450a554fb25b": {
#         "location": {
#             "name": "cus-5c6fc123-cf6a-41f8-9ce3-a9d80ddceaa8",
#             "lat": 40.640608,
#             "lng": -3.7070803
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 91,
#             "volume": 376
#         },
#         "priority": "low"
#     }
# }

# %%
import requests

# Define your fleet setup here (this is an example based on previous information)
def build_fleet(depots, num_drivers, shift_start, shift_end, weight, volume, drivers_per_depot):
    fleet = {
        f"driver_{driver_counter}": {
            "start_location": {
                "id": depot["id"],
                "name": depot["name"],
                "lat": depot["lat"],
                "lng": depot["lng"]
            },
            "end_location": {
                "id": depot["id"],
                "name": depot["name"],
                "lat": depot["lat"],
                "lng": depot["lng"]
            },
            "shift_start": shift_start,
            "shift_end": shift_end,
            "min_visits": 1,
            "capacity": {
                "weight": weight,
                "volume": volume
            }
        }
        for depot in depots
        for driver_counter in range(1, num_drivers + 1)
        if driver_counter <= num_drivers and (driver_counter - 1) // drivers_per_depot < len(depots)
    }
    
    return fleet

# Define depots and fleet parameters (based on your previous setup)
depots = [
    {"id": "depot_1", "name": "San Sebastian de los Reyes", "lat": 40.54510, "lng": -3.61184},
    {"id": "depot_2", "name": "Alcorcón", "lat": 40.350370, "lng": -3.855863},
    {"id": "depot_3", "name": "Vallecas", "lat": 40.36977, "lng": -3.59670}
]

# Build the fleet
fleet_for_routific = build_fleet(depots, num_drivers=18, shift_start="9:00", shift_end="18:00", weight=1500, volume=1500, drivers_per_depot=6)

# Combine the visits and fleet into the payload
payload = {
    "visits": visits_for_routific,
    "fleet": fleet_for_routific
}

# Combine with the config options if needed
config = {
   "options": {
       "traffic": "slow",
       "balance": True,
       "shortest_distance": True,
       "polylines": True
   }
}

# Final payload with config
combined_payload = {**payload, **config}

# Make the API request to Routific
routific_url = "https://api.routific.com/v1/vrp-long"
headers = {
    "Authorization": f"bearer {ROUTIFIC_TOKEN}",
    "Content-Type": "application/json"
}

response = requests.post(routific_url, headers=headers, json=combined_payload)

# Check the response and extract the job_id even if the status code is 202
if response.status_code == 200 or response.status_code == 202:
    print("Orders submitted to Routific. Processing in progress.")
    response_data = response.json()
    jobID = response_data.get("job_id")
    print(f"Job ID: {jobID}")
else:
    print(f"Failed to submit the orders. Status code: {response.status_code}")
    print("Response:", response.text)
# Out:
# Orders submitted to Routific. Processing in progress.
# Job ID: m1r86ecm522

# %%
import urllib3
import json
import time

def check_job_status(URL, jobID, headers, waiting_time):
    http = urllib3.PoolManager()
    URL = f"{URL}/{jobID}"
    job_status = None

    while job_status != 'finished':
        response = http.request('GET', URL, headers=headers)
        solution_data = json.loads(response.data.decode('utf-8'))
        job_status = solution_data.get('status')

        print("Current job status:", job_status)

        if job_status in ['pending', 'processing']:
            time.sleep(waiting_time)
        elif job_status == 'finished':
            print("Job finished.")
            return solution_data
        else:
            print("Unexpected job status:", job_status)
            break

# Example usage
solution_data = check_job_status("https://api.routific.com/jobs", jobID, headers, waiting_time=10)
# Out:
# Current job status: processing
# Current job status: finished
# Job finished.

# %%
# Iterate over the response and print the key-value structure
def print_key_value_structure(data, indent=''):
    for key, value in data.items():
        print(f"{indent}Key: {key} - Value Type: {type(value)}")
        if isinstance(value, dict):
            print_key_value_structure(value, indent + '  ')

# %%
# Print structure of the response_data
print_key_value_structure(solution_data)
# Out:
# Key: timing - Value Type: <class 'dict'>
#   Key: startedProcessingAt - Value Type: <class 'str'>
#   Key: finishedProcessingAt - Value Type: <class 'str'>
# Key: fetchedCount - Value Type: <class 'int'>
# Key: apiMajorVersion - Value Type: <class 'int'>
# Key: apiMinorVersion - Value Type: <class 'int'>
# Key: _id - Value Type: <class 'str'>
# Key: input - Value Type: <class 'dict'>
#   Key: visits - Value Type: <class 'dict'>
#     Key: 140680f5-cbf9-4056-922e-2ff935a078f2 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 9b442566-8a8b-4081-b6fd-87ff8cb1be2e - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 6ba61fa1-8590-4e43-a3d5-440268d80b52 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: ae7715ce-7714-4d2e-8beb-6e4e69e3ca72 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 0562e23b-c8c5-41d8-9312-e1e7afa0898d - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: b26faf91-8581-47c5-8a7a-bcab8ef664a9 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 64bd7522-0a7f-44e0-a79f-450a554fb25b - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#   Key: fleet - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_2 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_3 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_4 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_5 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_6 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_7 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_8 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_9 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_10 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_11 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_12 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_13 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_14 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_15 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_16 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_17 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_18 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#   Key: options - Value Type: <class 'dict'>
#     Key: traffic - Value Type: <class 'str'>
#     Key: balance - Value Type: <class 'bool'>
#     Key: shortest_distance - Value Type: <class 'bool'>
#     Key: polylines - Value Type: <class 'bool'>
#     Key: shortestDistance - Value Type: <class 'bool'>
#   Key: network - Value Type: <class 'dict'>
#     Key: 140680f5-cbf9-4056-922e-2ff935a078f2 - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#     Key: 9b442566-8a8b-4081-b6fd-87ff8cb1be2e - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#     Key: 6ba61fa1-8590-4e43-a3d5-440268d80b52 - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#     Key: ae7715ce-7714-4d2e-8beb-6e4e69e3ca72 - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#     Key: 0562e23b-c8c5-41d8-9312-e1e7afa0898d - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#     Key: b26faf91-8581-47c5-8a7a-bcab8ef664a9 - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#     Key: 64bd7522-0a7f-44e0-a79f-450a554fb25b - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#     Key: depot_3 - Value Type: <class 'dict'>
#       Key: name - Value Type: <class 'str'>
#       Key: lat - Value Type: <class 'float'>
#       Key: lng - Value Type: <class 'float'>
#       Key: _id - Value Type: <class 'str'>
#   Key: unserved - Value Type: <class 'NoneType'>
# Key: opts - Value Type: <class 'dict'>
#   Key: traffic - Value Type: <class 'float'>
#   Key: balance - Value Type: <class 'bool'>
#   Key: shortest_distance - Value Type: <class 'bool'>
#   Key: polylines - Value Type: <class 'bool'>
#   Key: shortestDistance - Value Type: <class 'bool'>
#   Key: time_format - Value Type: <class 'str'>
#   Key: problem - Value Type: <class 'str'>
# Key: _user - Value Type: <class 'str'>
# Key: id - Value Type: <class 'str'>
# Key: status - Value Type: <class 'str'>
# Key: createdAt - Value Type: <class 'str'>
# Key: visits - Value Type: <class 'int'>
# Key: fleet - Value Type: <class 'int'>
# Key: region - Value Type: <class 'str'>
# Key: requestId - Value Type: <class 'str'>
# Key: apiVersion - Value Type: <class 'str'>
# Key: __v - Value Type: <class 'int'>
# Key: eligibleTime - Value Type: <class 'str'>
# Key: lastWorkedAt - Value Type: <class 'str'>
# Key: finished_at - Value Type: <class 'str'>
# Key: output - Value Type: <class 'dict'>
#   Key: total_travel_time - Value Type: <class 'int'>
#   Key: total_idle_time - Value Type: <class 'int'>
#   Key: total_visit_lateness - Value Type: <class 'int'>
#   Key: total_vehicle_overtime - Value Type: <class 'int'>
#   Key: vehicle_overtime - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'int'>
#     Key: driver_10 - Value Type: <class 'int'>
#     Key: driver_11 - Value Type: <class 'int'>
#     Key: driver_12 - Value Type: <class 'int'>
#     Key: driver_13 - Value Type: <class 'int'>
#     Key: driver_14 - Value Type: <class 'int'>
#     Key: driver_15 - Value Type: <class 'int'>
#     Key: driver_16 - Value Type: <class 'int'>
#     Key: driver_17 - Value Type: <class 'int'>
#     Key: driver_18 - Value Type: <class 'int'>
#     Key: driver_2 - Value Type: <class 'int'>
#     Key: driver_3 - Value Type: <class 'int'>
#     Key: driver_4 - Value Type: <class 'int'>
#     Key: driver_5 - Value Type: <class 'int'>
#     Key: driver_6 - Value Type: <class 'int'>
#     Key: driver_7 - Value Type: <class 'int'>
#     Key: driver_8 - Value Type: <class 'int'>
#     Key: driver_9 - Value Type: <class 'int'>
#   Key: total_break_time - Value Type: <class 'int'>
#   Key: num_unserved - Value Type: <class 'int'>
#   Key: unserved - Value Type: <class 'NoneType'>
#   Key: solution - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'list'>
#     Key: driver_10 - Value Type: <class 'list'>
#     Key: driver_11 - Value Type: <class 'list'>
#     Key: driver_12 - Value Type: <class 'list'>
#     Key: driver_13 - Value Type: <class 'list'>
#     Key: driver_14 - Value Type: <class 'list'>
#     Key: driver_15 - Value Type: <class 'list'>
#     Key: driver_16 - Value Type: <class 'list'>
#     Key: driver_17 - Value Type: <class 'list'>
#     Key: driver_18 - Value Type: <class 'list'>
#     Key: driver_2 - Value Type: <class 'list'>
#     Key: driver_3 - Value Type: <class 'list'>
#     Key: driver_4 - Value Type: <class 'list'>
#     Key: driver_5 - Value Type: <class 'list'>
#     Key: driver_6 - Value Type: <class 'list'>
#     Key: driver_7 - Value Type: <class 'list'>
#     Key: driver_8 - Value Type: <class 'list'>
#     Key: driver_9 - Value Type: <class 'list'>
#   Key: total_working_time - Value Type: <class 'int'>
#   Key: status - Value Type: <class 'str'>
#   Key: pl_precision - Value Type: <class 'int'>
#   Key: polylines - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'list'>
#     Key: driver_10 - Value Type: <class 'list'>
#     Key: driver_11 - Value Type: <class 'list'>
#     Key: driver_12 - Value Type: <class 'list'>
#     Key: driver_13 - Value Type: <class 'list'>
#     Key: driver_14 - Value Type: <class 'list'>
#     Key: driver_15 - Value Type: <class 'list'>
#     Key: driver_16 - Value Type: <class 'list'>
#     Key: driver_17 - Value Type: <class 'list'>
#     Key: driver_18 - Value Type: <class 'list'>
#     Key: driver_2 - Value Type: <class 'list'>
#     Key: driver_3 - Value Type: <class 'list'>
#     Key: driver_4 - Value Type: <class 'list'>
#     Key: driver_5 - Value Type: <class 'list'>
#     Key: driver_6 - Value Type: <class 'list'>
#     Key: driver_7 - Value Type: <class 'list'>
#     Key: driver_8 - Value Type: <class 'list'>
#     Key: driver_9 - Value Type: <class 'list'>
#   Key: distances - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'float'>
#     Key: driver_10 - Value Type: <class 'int'>
#     Key: driver_11 - Value Type: <class 'int'>
#     Key: driver_12 - Value Type: <class 'int'>
#     Key: driver_13 - Value Type: <class 'int'>
#     Key: driver_14 - Value Type: <class 'int'>
#     Key: driver_15 - Value Type: <class 'int'>
#     Key: driver_16 - Value Type: <class 'int'>
#     Key: driver_17 - Value Type: <class 'int'>
#     Key: driver_18 - Value Type: <class 'int'>
#     Key: driver_2 - Value Type: <class 'float'>
#     Key: driver_3 - Value Type: <class 'float'>
#     Key: driver_4 - Value Type: <class 'float'>
#     Key: driver_5 - Value Type: <class 'float'>
#     Key: driver_6 - Value Type: <class 'float'>
#     Key: driver_7 - Value Type: <class 'float'>
#     Key: driver_8 - Value Type: <class 'int'>
#     Key: driver_9 - Value Type: <class 'int'>
#   Key: total_distance - Value Type: <class 'float'>
#   Key: num_late_visits - Value Type: <class 'int'>

# %%
# Print the output from the response_data
solution_data['output']['solution']
# Out:
# {'driver_1': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': '140680f5-cbf9-4056-922e-2ff935a078f2',
#    'location_name': 'cus-ba8d32e6-6f9c-4ddb-a0a0-bdc936739fbb',
#    'arrival_time': '10:07',
#    'finish_time': '10:12',
#    'distance': 37909.9},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '11:20',
#    'distance': 39252.5}],
#  'driver_10': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_11': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_12': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_13': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_14': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_15': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_16': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_17': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_18': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_2': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'b26faf91-8581-47c5-8a7a-bcab8ef664a9',
#    'location_name': 'cus-bbf84676-a48e-4beb-8758-22a8bbcdbd03',
#    'arrival_time': '09:23',
#    'finish_time': '09:28',
#    'distance': 8303.3},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:49',
#    'distance': 8430.5}],
#  'driver_3': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': '9b442566-8a8b-4081-b6fd-87ff8cb1be2e',
#    'location_name': 'cus-012169ba-74fe-44ad-b7f7-48923011499a',
#    'arrival_time': '09:45',
#    'finish_time': '09:50',
#    'distance': 25808.6},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '10:31',
#    'distance': 23389}],
#  'driver_4': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': '0562e23b-c8c5-41d8-9312-e1e7afa0898d',
#    'location_name': 'cus-4b7057d8-c3dd-4449-b4dc-5f4c15a4bdb6',
#    'arrival_time': '09:46',
#    'finish_time': '09:51',
#    'distance': 30492.5},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '10:42',
#    'distance': 30871.6}],
#  'driver_5': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': '6ba61fa1-8590-4e43-a3d5-440268d80b52',
#    'location_name': 'cus-e54fd919-0cd3-40e3-801b-3aa4f0015c6a',
#    'arrival_time': '09:53',
#    'finish_time': '09:58',
#    'distance': 36051.5},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '10:46',
#    'distance': 30628.8}],
#  'driver_6': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'ae7715ce-7714-4d2e-8beb-6e4e69e3ca72',
#    'location_name': 'cus-99e1c03c-9e4d-4a38-92b4-34819d8a1909',
#    'arrival_time': '10:25',
#    'finish_time': '10:30',
#    'distance': 42331},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '11:54',
#    'distance': 43617}],
#  'driver_7': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': '64bd7522-0a7f-44e0-a79f-450a554fb25b',
#    'location_name': 'cus-5c6fc123-cf6a-41f8-9ce3-a9d80ddceaa8',
#    'arrival_time': '11:32',
#    'finish_time': '11:37',
#    'distance': 59794.1},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '13:24',
#    'distance': 50324}],
#  'driver_8': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}],
#  'driver_9': [{'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0},
#   {'location_id': 'depot_3',
#    'location_name': 'Vallecas',
#    'arrival_time': '09:00',
#    'distance': 0}]}

# %%
from datetime import datetime, timedelta
from pyspark.sql.functions import lit, col

# Extract the served 'cus' IDs and finish times from the solution
served_customers = []
for driver, stops in solution_data['output']['solution'].items():
    for stop in stops:
        # Only process stops with customer IDs (which start with 'cus-')
        if stop['location_name'].startswith('cus-'):
            served_customers.append((stop['location_name'], stop['finish_time']))

# Debugging: Print the served customers
print("Served customers:", served_customers)

# Convert the finish_time into a timestamp and add one day
for index, (cus_id, finish_time) in enumerate(served_customers):
    try:
        # Assuming the finish_time is in 'HH:MM' format, append a date and parse it
        finish_time_obj = datetime.strptime(finish_time, '%H:%M')
        updated_finish_time = datetime.now().replace(hour=finish_time_obj.hour, minute=finish_time_obj.minute) + timedelta(days=1)
        served_customers[index] = (cus_id, updated_finish_time)
    except ValueError as e:
        print(f"Error parsing finish_time '{finish_time}' for cus_id '{cus_id}': {e}")

# Debugging: Print served customers after time adjustment
print("Served customers after time adjustment:", served_customers)
# Out:
# Served customers: [('cus-ba8d32e6-6f9c-4ddb-a0a0-bdc936739fbb', '10:12'), ('cus-bbf84676-a48e-4beb-8758-22a8bbcdbd03', '09:28'), ('cus-012169ba-74fe-44ad-b7f7-48923011499a', '09:50'), ('cus-4b7057d8-c3dd-4449-b4dc-5f4c15a4bdb6', '09:51'), ('cus-e54fd919-0cd3-40e3-801b-3aa4f0015c6a', '09:58'), ('cus-99e1c03c-9e4d-4a38-92b4-34819d8a1909', '10:30'), ('cus-5c6fc123-cf6a-41f8-9ce3-a9d80ddceaa8', '11:37')]
# Served customers after time adjustment: [('cus-ba8d32e6-6f9c-4ddb-a0a0-bdc936739fbb', datetime.datetime(2024, 10, 3, 10, 12, 25, 809208)), ('cus-bbf84676-a48e-4beb-8758-22a8bbcdbd03', datetime.datetime(2024, 10, 3, 9, 28, 25, 809229)), ('cus-012169ba-74fe-44ad-b7f7-48923011499a', datetime.datetime(2024, 10, 3, 9, 50, 25, 809239)), ('cus-4b7057d8-c3dd-4449-b4dc-5f4c15a4bdb6', datetime.datetime(2024, 10, 3, 9, 51, 25, 809248)), ('cus-e54fd919-0cd3-40e3-801b-3aa4f0015c6a', datetime.datetime(2024, 10, 3, 9, 58, 25, 809256)), ('cus-99e1c03c-9e4d-4a38-92b4-34819d8a1909', datetime.datetime(2024, 10, 3, 10, 30, 25, 809263)), ('cus-5c6fc123-cf6a-41f8-9ce3-a9d80ddceaa8', datetime.datetime(2024, 10, 3, 11, 37, 25, 809271))]

# %%
from pyspark.sql.functions import lit, col
from delta.tables import DeltaTable

# Function to overwrite Delta table with the updated 'DISPATCHED' records
def overwrite_delta_table(served_customers, delta_table_path):
    # Read the Delta table into a DataFrame
    delta_table = DeltaTable.forPath(spark, delta_table_path)
    df = delta_table.toDF()

    # Create a DataFrame from the served customers list
    served_df = spark.createDataFrame(served_customers, ['served_customer_id', 'updated_finish_time'])

    # Rename the column in served_df to avoid ambiguity during the join
    served_df = served_df.withColumnRenamed('updated_finish_time', 'new_finish_time')

    # Update the records that match the served customers
    updated_df = df.join(served_df, df.customer_id == served_df.served_customer_id, 'inner') \
        .withColumn('status', lit('DISPATCHED')) \
        .withColumn('order_timestamp', col('new_finish_time'))  # Use the renamed column

    # Overwrite only the affected rows in the Delta table
    delta_table.alias('old') \
        .merge(updated_df.alias('new'), 'old.customer_id = new.served_customer_id') \
        .whenMatchedUpdate(set={
            "status": col('new.status'),
            "order_timestamp": col('new.new_finish_time')  # Use the renamed column
        }) \
        .execute()

    # Display the updated Delta table without the extra columns
    df_updated = delta_table.toDF().drop('served_customer_id', 'new_finish_time')
    df_updated.filter(df_updated.status.isin('DISPATCHED', 'READY_FOR_DISPATCH')).show(truncate=False)

# Call the function to overwrite the Delta table with the updated records
overwrite_delta_table(served_customers, delta_table_path)
# Out:
# [Stage 79:>                                                         (0 + 1) / 1]
# +------------------------------------+----------------------------------------+-----------------+------------------+------------------+--------------------------+------------------+------------------+-------------------+
# |order_id                            |customer_id                             |total_weight     |total_volume      |total_price       |order_timestamp           |status            |lat               |lon                |
# +------------------------------------+----------------------------------------+-----------------+------------------+------------------+--------------------------+------------------+------------------+-------------------+
# |9b442566-8a8b-4081-b6fd-87ff8cb1be2e|cus-012169ba-74fe-44ad-b7f7-48923011499a|48.73753836832661|242.98560297383696|572.0745375784338 |2024-10-03 09:50:25.809239|DISPATCHED        |40.41326882171988 |-3.7854324815045137|
# |140680f5-cbf9-4056-922e-2ff935a078f2|cus-ba8d32e6-6f9c-4ddb-a0a0-bdc936739fbb|82.73160870030328|318.9174240318443 |412.70773183574084|2024-10-03 10:12:25.809208|DISPATCHED        |40.5202115180548  |-3.8638075430981003|
# |0562e23b-c8c5-41d8-9312-e1e7afa0898d|cus-4b7057d8-c3dd-4449-b4dc-5f4c15a4bdb6|46.74087426850831|392.79371443806525|312.49896608574   |2024-10-03 09:51:25.809248|DISPATCHED        |40.570276017311635|-3.632292221828427 |
# |6ba61fa1-8590-4e43-a3d5-440268d80b52|cus-e54fd919-0cd3-40e3-801b-3aa4f0015c6a|43.53990041187081|139.95677803342312|420.68691285213123|2024-10-03 09:58:25.809256|DISPATCHED        |40.56735698592657 |-3.7339000542917575|
# |ae7715ce-7714-4d2e-8beb-6e4e69e3ca72|cus-99e1c03c-9e4d-4a38-92b4-34819d8a1909|48.12950760579068|460.40128508892   |928.9953000140409 |2024-10-03 10:30:25.809263|DISPATCHED        |40.55352027399454 |-3.846850240184429 |
# |64bd7522-0a7f-44e0-a79f-450a554fb25b|cus-5c6fc123-cf6a-41f8-9ce3-a9d80ddceaa8|90.67317748547849|375.40339945429565|291.02050389950824|2024-10-03 11:37:25.809271|DISPATCHED        |40.64060844221572 |-3.7070802941843075|
# |b26faf91-8581-47c5-8a7a-bcab8ef664a9|cus-bbf84676-a48e-4beb-8758-22a8bbcdbd03|38.75207275621183|270.4332401055019 |36.17281916219022 |2024-10-03 09:28:25.809229|DISPATCHED        |40.37381234111349 |-3.6619045311504714|
# |8d6adae1-e68d-4e59-aeef-5eb0c1c6227f|cus-49f84bcc-69f8-4be7-94ef-17a0a2d80f2c|92.60351507581612|242.4883615375743 |880.1691661195565 |2024-10-02 04:05:29       |READY_FOR_DISPATCH|40.58116490703484 |-3.7770963729789564|
# +------------------------------------+----------------------------------------+-----------------+------------------+------------------+--------------------------+------------------+------------------+-------------------+

# %%
# Function to show Delta table with both 'DISPATCHED' and 'READY_FOR_DISPATCH' statuses
def show_dispatch_status(limit=None):
    delta_table = DeltaTable.forPath(spark, delta_table_path)
    df = delta_table.toDF()
    
    # Filter for both 'DISPATCHED' and 'READY_FOR_DISPATCH' statuses
    filtered_df = df.filter(df.status.isin('DISPATCHED', 'READY_FOR_DISPATCH'))
    
    # Show all rows (or a limited number if specified)
    if limit is not None:
        filtered_df.show(limit, truncate=False)
    else:
        filtered_df.show(truncate=False)

# Display the updated Delta table with an increased row limit (e.g., 100 rows)
show_dispatch_status(limit=100)  # Adjust limit as needed
# Out:
# [Stage 85:>                                                         (0 + 2) / 2]
# +------------------------------------+----------------------------------------+-----------------+------------------+------------------+--------------------------+------------------+------------------+-------------------+
# |order_id                            |customer_id                             |total_weight     |total_volume      |total_price       |order_timestamp           |status            |lat               |lon                |
# +------------------------------------+----------------------------------------+-----------------+------------------+------------------+--------------------------+------------------+------------------+-------------------+
# |9b442566-8a8b-4081-b6fd-87ff8cb1be2e|cus-012169ba-74fe-44ad-b7f7-48923011499a|48.73753836832661|242.98560297383696|572.0745375784338 |2024-10-03 09:50:25.809239|DISPATCHED        |40.41326882171988 |-3.7854324815045137|
# |140680f5-cbf9-4056-922e-2ff935a078f2|cus-ba8d32e6-6f9c-4ddb-a0a0-bdc936739fbb|82.73160870030328|318.9174240318443 |412.70773183574084|2024-10-03 10:12:25.809208|DISPATCHED        |40.5202115180548  |-3.8638075430981003|
# |0562e23b-c8c5-41d8-9312-e1e7afa0898d|cus-4b7057d8-c3dd-4449-b4dc-5f4c15a4bdb6|46.74087426850831|392.79371443806525|312.49896608574   |2024-10-03 09:51:25.809248|DISPATCHED        |40.570276017311635|-3.632292221828427 |
# |6ba61fa1-8590-4e43-a3d5-440268d80b52|cus-e54fd919-0cd3-40e3-801b-3aa4f0015c6a|43.53990041187081|139.95677803342312|420.68691285213123|2024-10-03 09:58:25.809256|DISPATCHED        |40.56735698592657 |-3.7339000542917575|
# |ae7715ce-7714-4d2e-8beb-6e4e69e3ca72|cus-99e1c03c-9e4d-4a38-92b4-34819d8a1909|48.12950760579068|460.40128508892   |928.9953000140409 |2024-10-03 10:30:25.809263|DISPATCHED        |40.55352027399454 |-3.846850240184429 |
# |64bd7522-0a7f-44e0-a79f-450a554fb25b|cus-5c6fc123-cf6a-41f8-9ce3-a9d80ddceaa8|90.67317748547849|375.40339945429565|291.02050389950824|2024-10-03 11:37:25.809271|DISPATCHED        |40.64060844221572 |-3.7070802941843075|
# |b26faf91-8581-47c5-8a7a-bcab8ef664a9|cus-bbf84676-a48e-4beb-8758-22a8bbcdbd03|38.75207275621183|270.4332401055019 |36.17281916219022 |2024-10-03 09:28:25.809229|DISPATCHED        |40.37381234111349 |-3.6619045311504714|
# |8d6adae1-e68d-4e59-aeef-5eb0c1c6227f|cus-49f84bcc-69f8-4be7-94ef-17a0a2d80f2c|92.60351507581612|242.4883615375743 |880.1691661195565 |2024-10-02 04:05:29       |READY_FOR_DISPATCH|40.58116490703484 |-3.7770963729789564|
# |4b940677-dd12-4e2c-9613-0fe1a7aa1760|cus-1a53dfa5-de42-4e91-aa67-7dfd3e07e22d|52.89003629329177|46.821241954089196|879.0783040278777 |2024-10-02 04:06:11       |READY_FOR_DISPATCH|40.529752244413984|-3.7012124227966563|
# +------------------------------------+----------------------------------------+-----------------+------------------+------------------+--------------------------+------------------+------------------+-------------------+
