# %%
import boto3
import json
import time
from dotenv import load_dotenv
from datetime import datetime
import os
from delta.tables import DeltaTable

# Load environment variables from .env file
load_dotenv()

# Initialize AWS credentials from the .env file
AWS_ACCESS_KEY_ID = os.getenv('AWS_ACCESS_KEY_ID')
AWS_SECRET_ACCESS_KEY = os.getenv('AWS_SECRET_ACCESS_KEY')
AWS_SESSION_TOKEN = os.getenv('AWS_SESSION_TOKEN')
AWS_REGION = os.getenv('AWS_REGION')
ROUTIFIC_TOKEN = os.getenv('ROUTIFIC_TOKEN')

# %%
# Initialize boto3 client for Kinesis with your credentials
kinesis_client = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    aws_session_token=AWS_SESSION_TOKEN,
    region_name=AWS_REGION
)

# Initialize boto3 client for S3 with your credentials
s3_client = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    aws_session_token=AWS_SESSION_TOKEN,
    region_name=AWS_REGION 
)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("DeltaTableReader") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0,org.apache.hadoop:hadoop-aws:3.3.1") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# Path to the Delta table in S3
delta_table_path = "s3a://orders-for-dispatch/ready_for_dispatch"
# Out:
# :: loading settings :: url = jar:file:/Users/borja/Library/Caches/pypoetry/virtualenvs/route-optimizer-AqO2e-Ud-py3.11/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/borja/.ivy2/cache
# The jars for the packages stored in: /Users/borja/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# org.apache.hadoop#hadoop-aws added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-1e5aa28a-9f69-4686-8ed2-df7469bccfc0;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# 	found org.apache.hadoop#hadoop-aws;3.3.1 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.11.901 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# :: resolution report :: resolve 137ms :: artifacts dl 5ms
# 	:: modules in use:
# 	com.amazonaws#aws-java-sdk-bundle;1.11.901 from central in [default]
# 	io.delta#delta-core_2.12;2.4.0 from central in [default]
# 	io.delta#delta-storage;2.4.0 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.1 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   6   |   0   |   0   |   0   ||   6   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-1e5aa28a-9f69-4686-8ed2-df7469bccfc0
# 	confs: [default]
# 	0 artifacts copied, 6 already retrieved (0kB/3ms)
# 24/10/03 03:30:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# Path to the Delta table in S3
delta_table_path = 's3a://orders-for-dispatch/dispatching'

# %%
# Function to read records marked as ready for dispatch
def read_ready_for_dispatch_orders():
    # Load the Delta table
    delta_table = DeltaTable.forPath(spark, delta_table_path)
    
    # Query the Delta table to fetch only the records marked as READY_FOR_DISPATCH
    df = delta_table.toDF().filter("status = 'READY_FOR_DISPATCH'")
    
    # Return the DataFrame
    return df

# %%
# Fetch the ready-for-dispatch orders
ready_orders_df = read_ready_for_dispatch_orders()

# Convert the DataFrame to a list of Row objects
ready_orders = ready_orders_df.collect()
# Out:
# 24/10/03 03:30:30 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# |84480db6-91fe-440...|cus-30e3b389-4422...|  72.1901243513759| 73.28362535583715| 677.8554469928214|2024-10-03 03:29:04|READY_FOR_DISPATCH| 40.56922872974951|-3.7982647031500174|
# |5745fd6b-50c3-431...|cus-2260441b-7585...| 58.88165842260217| 306.4266408049731|111.27774445952106|2024-10-03 03:28:53|READY_FOR_DISPATCH|40.428046957340584| -3.576625841448611|
# |00e87267-15f0-407...|cus-e614c9ff-ef42...| 58.44216192997558|408.22713743944286| 519.2051794051508|2024-10-03 03:29:27|READY_FOR_DISPATCH| 40.48277185569072|-3.6599028035634893|
# |5a3646c0-fc0d-48c...|cus-c85c717a-78fd...| 76.89711470276836| 189.4248487210732| 934.4575800252746|2024-10-03 03:30:01|READY_FOR_DISPATCH| 40.34432315392608| -3.756750482945305|
# |b961bacd-1430-495...|cus-0c77cf12-ac06...|3.1571422581544826|298.11847062150247| 731.8285689833602|2024-10-03 03:29:13|READY_FOR_DISPATCH| 40.64490857977663| -3.652433484248254|
# |c9c92207-9e3d-424...|cus-5b9324f6-e59f...| 39.08198158018332|311.76839696253967|479.83285898645164|2024-10-03 03:29:57|READY_FOR_DISPATCH| 40.33006194161545| -3.637714299861406|
# |6462ae5a-d92d-495...|cus-ca693a19-80da...|48.241366979967324|190.47766150235054| 900.3170878791465|2024-10-03 03:29:40|READY_FOR_DISPATCH|40.380652639144635| -3.859395593451745|
# |edcf7ff2-66b5-443...|cus-2a0cddf4-cfc0...|17.259033231844175| 445.6190094796965| 550.4551319757289|2024-10-03 03:29:09|READY_FOR_DISPATCH| 40.52626939841648|-3.5995964047383446|
# +--------------------+--------------------+------------------+------------------+------------------+-------------------+------------------+------------------+-------------------+
# only showing top 20 rows

# %%
import random
import numpy as np

# List of possible priorities
priorities = ["low", "regular", "high"]

# Function to write JSON with visits in the required format
def format_to_visits(data):
    if data is None:
        print("Data is None, cannot format visits.")
        return {}

    visits = {
        item['order_id']: {
            "location": {
                "name": item['customer_id'],  # Routific requires a 'name' field for each location
                "lat": round(item['lat'], 6),  # Latitude from your data
                "lng": round(item['lon'], 7)  # Longitude from your data (changed 'lon' to 'lng' for consistency with Routific API)
            },
            "start": "9:00",  # Default start time (customize if you have specific times)
            "end": "18:00",  # Default end time
            "duration": 5,  # Default duration (customize as needed)
            "load": {
                "weight": int(np.ceil(item['total_weight'])),  # Use the 'total_weight' from the row
                "volume": int(np.ceil(item['total_volume']))  # Use the 'total_volume' from the row
            },
            "priority": random.choice(priorities),  # Assign a random priority for each order
        } for item in data
    }
    return visits



# Step 3: Transform the orders into the Routific format
visits_for_routific = format_to_visits(ready_orders)

# Check the output to verify the visits are correctly formatted
print("Visits formatted for Routific API:")
print(json.dumps(visits_for_routific, indent=4))
# Out:
# Visits formatted for Routific API:
# {
#     "bfc9983d-23f7-4163-8c03-98cc7a041555": {
#         "location": {
#             "name": "cus-f1595d2d-7f14-455e-95f8-3cfa96d040e4",
#             "lat": 40.584293,
#             "lng": -3.6723276
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 49,
#             "volume": 152
#         },
#         "priority": "low"
#     },
#     "6f0b12bc-7dfc-4432-8b19-25a1d545ee26": {
#         "location": {
#             "name": "cus-c7255b5b-f67f-4f66-b5dc-1d340ab2cbeb",
#             "lat": 40.375877,
#             "lng": -3.8458456
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 31,
#             "volume": 362
#         },
#         "priority": "low"
#     },
#     "a2b89b86-13fb-4bf7-831b-72326bafabe3": {
#         "location": {
#             "name": "cus-6bf87077-5e08-4fd1-838f-f3006e2f58dc",
#             "lat": 40.325046,
#             "lng": -3.6601376
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 52,
#             "volume": 455
#         },
#         "priority": "low"
#     },
#     "a4079fc6-a8d5-4c0c-b527-f80c493d582e": {
#         "location": {
#             "name": "cus-1c2638df-a1c1-4e5e-89a4-ea6191fa09fb",
#             "lat": 40.41387,
#             "lng": -3.6560284
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 60,
#             "volume": 468
#         },
#         "priority": "high"
#     },
#     "19be4cd2-60bf-4e61-ab6f-72b6e181047d": {
#         "location": {
#             "name": "cus-65ca0831-b406-46f3-a6aa-4b5c4fdb9bf0",
#             "lat": 40.315897,
#             "lng": -3.7142863
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 95,
#             "volume": 189
#         },
#         "priority": "low"
#     },
#     "f492198f-bb13-4c07-ad78-1fe6e6a16849": {
#         "location": {
#             "name": "cus-2f527c49-a8e6-4d82-b936-2d6a4e1a752f",
#             "lat": 40.489682,
#             "lng": -3.8203396
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 31,
#             "volume": 349
#         },
#         "priority": "low"
#     },
#     "0f229ce5-284d-4755-87aa-48f7c8f5f756": {
#         "location": {
#             "name": "cus-45aaaea9-81d1-49fc-aba5-35692ba64573",
#             "lat": 40.330421,
#             "lng": -3.7813088
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 41,
#             "volume": 104
#         },
#         "priority": "low"
#     },
#     "f997139d-ac2c-4efb-8670-3d357a2c4f83": {
#         "location": {
#             "name": "cus-2bdcc414-58ea-4f84-8e3a-e830a68dfdeb",
#             "lat": 40.359449,
#             "lng": -3.6967146
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 57,
#             "volume": 187
#         },
#         "priority": "regular"
#     },
#     "672832ba-7972-4cb3-bd63-55d47800d25c": {
#         "location": {
#             "name": "cus-1e36370f-561f-4079-b666-c2e7723f2c0e",
#             "lat": 40.352257,
#             "lng": -3.7780006
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 45,
#             "volume": 129
#         },
#         "priority": "low"
#     },
#     "a2cd0a55-1478-4547-95a0-604e9064c322": {
#         "location": {
#             "name": "cus-d352a54f-081c-474f-9385-4cacfeb28550",
#             "lat": 40.414498,
#             "lng": -3.6476091
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 51,
#             "volume": 231
#         },
#         "priority": "low"
#     },
#     "bd0b02bd-31e0-4880-928a-c98faac904f3": {
#         "location": {
#             "name": "cus-a939ebd7-17ee-4f03-9d66-0143e6df5161",
#             "lat": 40.550462,
#             "lng": -3.7069521
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 89,
#             "volume": 268
#         },
#         "priority": "high"
#     },
#     "84480db6-91fe-440a-88a1-4db7e1a33d75": {
#         "location": {
#             "name": "cus-30e3b389-4422-45f2-9cd2-88786e803733",
#             "lat": 40.569229,
#             "lng": -3.7982647
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 73,
#             "volume": 74
#         },
#         "priority": "low"
#     },
#     "5745fd6b-50c3-4312-bb01-4166198341fe": {
#         "location": {
#             "name": "cus-2260441b-7585-4cff-b1e9-f9787083a80b",
#             "lat": 40.428047,
#             "lng": -3.5766258
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 59,
#             "volume": 307
#         },
#         "priority": "low"
#     },
#     "00e87267-15f0-4077-948a-1ab81ff2bd67": {
#         "location": {
#             "name": "cus-e614c9ff-ef42-4d5d-97ca-752c6edb75f8",
#             "lat": 40.482772,
#             "lng": -3.6599028
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 59,
#             "volume": 409
#         },
#         "priority": "low"
#     },
#     "5a3646c0-fc0d-48cc-b20a-26da8ab5c07e": {
#         "location": {
#             "name": "cus-c85c717a-78fd-4c44-b151-14387d4b8d74",
#             "lat": 40.344323,
#             "lng": -3.7567505
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 77,
#             "volume": 190
#         },
#         "priority": "high"
#     },
#     "b961bacd-1430-495e-9f16-97dcc45af8f8": {
#         "location": {
#             "name": "cus-0c77cf12-ac06-43b9-8a79-31afc67d7de1",
#             "lat": 40.644909,
#             "lng": -3.6524335
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 4,
#             "volume": 299
#         },
#         "priority": "high"
#     },
#     "c9c92207-9e3d-4248-9710-dedb9899ccb2": {
#         "location": {
#             "name": "cus-5b9324f6-e59f-403a-9505-802734cb9be5",
#             "lat": 40.330062,
#             "lng": -3.6377143
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 40,
#             "volume": 312
#         },
#         "priority": "high"
#     },
#     "6462ae5a-d92d-4953-b484-541c5b7c142f": {
#         "location": {
#             "name": "cus-ca693a19-80da-40a1-b8d3-377404f372d6",
#             "lat": 40.380653,
#             "lng": -3.8593956
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 49,
#             "volume": 191
#         },
#         "priority": "regular"
#     },
#     "edcf7ff2-66b5-443f-b6a2-d0ddf01f1b30": {
#         "location": {
#             "name": "cus-2a0cddf4-cfc0-45f8-8502-abe13dee4284",
#             "lat": 40.526269,
#             "lng": -3.5995964
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 18,
#             "volume": 446
#         },
#         "priority": "high"
#     },
#     "42661805-2649-4d4f-a1cc-ede1cfea2050": {
#         "location": {
#             "name": "cus-313f79db-bfc4-4775-b765-05525bc0f73f",
#             "lat": 40.378631,
#             "lng": -3.6613308
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 83,
#             "volume": 90
#         },
#         "priority": "low"
#     },
#     "45016b4c-539f-4018-aeed-0a1c16065c01": {
#         "location": {
#             "name": "cus-9ef25f15-402d-4544-bb89-cc34a8b6caad",
#             "lat": 40.347675,
#             "lng": -3.6064302
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 15,
#             "volume": 101
#         },
#         "priority": "low"
#     },
#     "2278325a-4750-4bf1-8dad-31674469c5d4": {
#         "location": {
#             "name": "cus-ecd091c4-91ee-4449-b9d2-7b38c0ed44d9",
#             "lat": 40.583863,
#             "lng": -3.7283528
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 2,
#             "volume": 122
#         },
#         "priority": "high"
#     },
#     "5399273a-82e1-4ca4-b437-effff04d670d": {
#         "location": {
#             "name": "cus-99826dbf-a9fe-431b-95e7-eb7e01c9e2b2",
#             "lat": 40.548886,
#             "lng": -3.7440104
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 97,
#             "volume": 171
#         },
#         "priority": "low"
#     },
#     "cfb7854d-d9f1-476c-92e1-49d122bdc28f": {
#         "location": {
#             "name": "cus-c42061b9-ecf7-43ec-b2a3-996da0e347e8",
#             "lat": 40.523645,
#             "lng": -3.8281741
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 3,
#             "volume": 448
#         },
#         "priority": "low"
#     },
#     "5bbb1b11-84b9-4063-a2b0-d5cba0a50915": {
#         "location": {
#             "name": "cus-607eff8c-4ad4-4a2e-8abe-1b72d8be173f",
#             "lat": 40.359049,
#             "lng": -3.6889593
#         },
#         "start": "9:00",
#         "end": "18:00",
#         "duration": 5,
#         "load": {
#             "weight": 94,
#             "volume": 264
#         },
#         "priority": "high"
#     }
# }

# %%
import requests

# Define your fleet setup here (this is an example based on previous information)
def build_fleet(depots, num_drivers, shift_start, shift_end, weight, volume, drivers_per_depot):
    fleet = {
        f"driver_{driver_counter}": {
            "start_location": {
                "id": depot["id"],
                "name": depot["name"],
                "lat": depot["lat"],
                "lng": depot["lng"]
            },
            "end_location": {
                "id": depot["id"],
                "name": depot["name"],
                "lat": depot["lat"],
                "lng": depot["lng"]
            },
            "shift_start": shift_start,
            "shift_end": shift_end,
            "min_visits": 1,
            "capacity": {
                "weight": weight,
                "volume": volume
            }
        }
        for depot in depots
        for driver_counter in range(1, num_drivers + 1)
        if driver_counter <= num_drivers and (driver_counter - 1) // drivers_per_depot < len(depots)
    }
    
    return fleet

# Define depots and fleet parameters (based on your previous setup)
depots = [
    {"id": "depot_1", "name": "San Sebastian de los Reyes", "lat": 40.54510, "lng": -3.61184},
    {"id": "depot_2", "name": "Alcorcón", "lat": 40.350370, "lng": -3.855863},
    {"id": "depot_3", "name": "Vallecas", "lat": 40.36977, "lng": -3.59670}
]

# Build the fleet
fleet_for_routific = build_fleet(depots, num_drivers=18, shift_start="9:00", shift_end="18:00", weight=1500, volume=1500, drivers_per_depot=6)

# Combine the visits and fleet into the payload
payload = {
    "visits": visits_for_routific,
    "fleet": fleet_for_routific
}

# Combine with the config options if needed
config = {
   "options": {
       "traffic": "slow",
       "balance": True,
       "shortest_distance": True,
       "polylines": True
   }
}

# Final payload with config
combined_payload = {**payload, **config}

# Make the API request to Routific
routific_url = "https://api.routific.com/v1/vrp-long"
headers = {
    "Authorization": f"bearer {ROUTIFIC_TOKEN}",
    "Content-Type": "application/json"
}

response = requests.post(routific_url, headers=headers, json=combined_payload)

# Check the response and extract the job_id even if the status code is 202
if response.status_code == 200 or response.status_code == 202:
    print("Orders submitted to Routific. Processing in progress.")
    response_data = response.json()
    jobID = response_data.get("job_id")
    print(f"Job ID: {jobID}")
else:
    print(f"Failed to submit the orders. Status code: {response.status_code}")
    print("Response:", response.text)
# Out:
# Orders submitted to Routific. Processing in progress.
# Job ID: m1smebqq71

# %%
import urllib3
import json
import time

def check_job_status(URL, jobID, headers, waiting_time):
    http = urllib3.PoolManager()
    URL = f"{URL}/{jobID}"
    job_status = None

    while job_status != 'finished':
        response = http.request('GET', URL, headers=headers)
        solution_data = json.loads(response.data.decode('utf-8'))
        job_status = solution_data.get('status')

        print("Current job status:", job_status)

        if job_status in ['pending', 'processing']:
            time.sleep(waiting_time)
        elif job_status == 'finished':
            print("Job finished.")
            return solution_data
        else:
            print("Unexpected job status:", job_status)
            break

# Example usage
solution_data = check_job_status("https://api.routific.com/jobs", jobID, headers, waiting_time=10)
# Out:
# Current job status: processing
# Current job status: finished
# Job finished.

# %%
# Iterate over the response and print the key-value structure
def print_key_value_structure(data, indent=''):
    for key, value in data.items():
        print(f"{indent}Key: {key} - Value Type: {type(value)}")
        if isinstance(value, dict):
            print_key_value_structure(value, indent + '  ')

# %%
# Print structure of the response_data
print_key_value_structure(solution_data)
# Out:
# Key: timing - Value Type: <class 'dict'>
#   Key: startedProcessingAt - Value Type: <class 'str'>
#   Key: finishedProcessingAt - Value Type: <class 'str'>
# Key: fetchedCount - Value Type: <class 'int'>
# Key: apiMajorVersion - Value Type: <class 'int'>
# Key: apiMinorVersion - Value Type: <class 'int'>
# Key: _id - Value Type: <class 'str'>
# Key: input - Value Type: <class 'dict'>
#   Key: visits - Value Type: <class 'dict'>
#     Key: bfc9983d-23f7-4163-8c03-98cc7a041555 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 6f0b12bc-7dfc-4432-8b19-25a1d545ee26 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: a2b89b86-13fb-4bf7-831b-72326bafabe3 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: a4079fc6-a8d5-4c0c-b527-f80c493d582e - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 19be4cd2-60bf-4e61-ab6f-72b6e181047d - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: f492198f-bb13-4c07-ad78-1fe6e6a16849 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 0f229ce5-284d-4755-87aa-48f7c8f5f756 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: f997139d-ac2c-4efb-8670-3d357a2c4f83 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 672832ba-7972-4cb3-bd63-55d47800d25c - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: a2cd0a55-1478-4547-95a0-604e9064c322 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: bd0b02bd-31e0-4880-928a-c98faac904f3 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 84480db6-91fe-440a-88a1-4db7e1a33d75 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 5745fd6b-50c3-4312-bb01-4166198341fe - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 00e87267-15f0-4077-948a-1ab81ff2bd67 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 5a3646c0-fc0d-48cc-b20a-26da8ab5c07e - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: b961bacd-1430-495e-9f16-97dcc45af8f8 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: c9c92207-9e3d-4248-9710-dedb9899ccb2 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 6462ae5a-d92d-4953-b484-541c5b7c142f - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: edcf7ff2-66b5-443f-b6a2-d0ddf01f1b30 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 42661805-2649-4d4f-a1cc-ede1cfea2050 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 45016b4c-539f-4018-aeed-0a1c16065c01 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 2278325a-4750-4bf1-8dad-31674469c5d4 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 5399273a-82e1-4ca4-b437-effff04d670d - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: cfb7854d-d9f1-476c-92e1-49d122bdc28f - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: 5bbb1b11-84b9-4063-a2b0-d5cba0a50915 - Value Type: <class 'dict'>
#       Key: location - Value Type: <class 'dict'>
#         Key: name - Value Type: <class 'str'>
#         Key: lat - Value Type: <class 'float'>
#         Key: lng - Value Type: <class 'float'>
#       Key: start - Value Type: <class 'str'>
#       Key: end - Value Type: <class 'str'>
#       Key: duration - Value Type: <class 'int'>
#       Key: load - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#       Key: priority - Value Type: <class 'int'>
#       Key: time_windows - Value Type: <class 'list'>
#       Key: typedDemand - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#   Key: fleet - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_2 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_3 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_4 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_5 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_6 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_7 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_8 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_9 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_10 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_11 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_12 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_13 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_14 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_15 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_16 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
#     Key: driver_17 - Value Type: <class 'dict'>
#       Key: start-location - Value Type: <class 'str'>
#       Key: end-location - Value Type: <class 'str'>
#       Key: shift-start - Value Type: <class 'str'>
#       Key: shift-end - Value Type: <class 'str'>
#       Key: min-visits - Value Type: <class 'int'>
#       Key: typedCapacity - Value Type: <class 'dict'>
#         Key: weight - Value Type: <class 'int'>
#         Key: volume - Value Type: <class 'int'>
# Key: lastWorkedAt - Value Type: <class 'str'>
# Key: finished_at - Value Type: <class 'str'>
# Key: output - Value Type: <class 'dict'>
#   Key: total_travel_time - Value Type: <class 'int'>
#   Key: total_idle_time - Value Type: <class 'int'>
#   Key: total_visit_lateness - Value Type: <class 'int'>
#   Key: total_vehicle_overtime - Value Type: <class 'int'>
#   Key: vehicle_overtime - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'int'>
#     Key: driver_10 - Value Type: <class 'int'>
#     Key: driver_11 - Value Type: <class 'int'>
#     Key: driver_12 - Value Type: <class 'int'>
#     Key: driver_13 - Value Type: <class 'int'>
#     Key: driver_14 - Value Type: <class 'int'>
#     Key: driver_15 - Value Type: <class 'int'>
#     Key: driver_16 - Value Type: <class 'int'>
#     Key: driver_17 - Value Type: <class 'int'>
#     Key: driver_18 - Value Type: <class 'int'>
#     Key: driver_2 - Value Type: <class 'int'>
#     Key: driver_3 - Value Type: <class 'int'>
#     Key: driver_4 - Value Type: <class 'int'>
#     Key: driver_5 - Value Type: <class 'int'>
#     Key: driver_6 - Value Type: <class 'int'>
#     Key: driver_7 - Value Type: <class 'int'>
#     Key: driver_8 - Value Type: <class 'int'>
#     Key: driver_9 - Value Type: <class 'int'>
#   Key: total_break_time - Value Type: <class 'int'>
#   Key: num_unserved - Value Type: <class 'int'>
#   Key: unserved - Value Type: <class 'NoneType'>
#   Key: solution - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'list'>
#     Key: driver_10 - Value Type: <class 'list'>
#     Key: driver_11 - Value Type: <class 'list'>
#     Key: driver_12 - Value Type: <class 'list'>
#     Key: driver_13 - Value Type: <class 'list'>
#     Key: driver_14 - Value Type: <class 'list'>
#     Key: driver_15 - Value Type: <class 'list'>
#     Key: driver_16 - Value Type: <class 'list'>
#     Key: driver_17 - Value Type: <class 'list'>
#     Key: driver_18 - Value Type: <class 'list'>
#     Key: driver_2 - Value Type: <class 'list'>
#     Key: driver_3 - Value Type: <class 'list'>
#     Key: driver_4 - Value Type: <class 'list'>
#     Key: driver_5 - Value Type: <class 'list'>
#     Key: driver_6 - Value Type: <class 'list'>
#     Key: driver_7 - Value Type: <class 'list'>
#     Key: driver_8 - Value Type: <class 'list'>
#     Key: driver_9 - Value Type: <class 'list'>
#   Key: total_working_time - Value Type: <class 'int'>
#   Key: status - Value Type: <class 'str'>
#   Key: pl_precision - Value Type: <class 'int'>
#   Key: polylines - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'list'>
#     Key: driver_10 - Value Type: <class 'list'>
#     Key: driver_11 - Value Type: <class 'list'>
#     Key: driver_12 - Value Type: <class 'list'>
#     Key: driver_13 - Value Type: <class 'list'>
#     Key: driver_14 - Value Type: <class 'list'>
#     Key: driver_15 - Value Type: <class 'list'>
#     Key: driver_16 - Value Type: <class 'list'>
#     Key: driver_17 - Value Type: <class 'list'>
#     Key: driver_18 - Value Type: <class 'list'>
#     Key: driver_2 - Value Type: <class 'list'>
#     Key: driver_3 - Value Type: <class 'list'>
#     Key: driver_4 - Value Type: <class 'list'>
#     Key: driver_5 - Value Type: <class 'list'>
#     Key: driver_6 - Value Type: <class 'list'>
#     Key: driver_7 - Value Type: <class 'list'>
#     Key: driver_8 - Value Type: <class 'list'>
#     Key: driver_9 - Value Type: <class 'list'>
#   Key: distances - Value Type: <class 'dict'>
#     Key: driver_1 - Value Type: <class 'float'>
#     Key: driver_10 - Value Type: <class 'float'>
#     Key: driver_11 - Value Type: <class 'float'>
#     Key: driver_12 - Value Type: <class 'float'>
#     Key: driver_13 - Value Type: <class 'float'>
#     Key: driver_14 - Value Type: <class 'float'>
#     Key: driver_15 - Value Type: <class 'float'>
#     Key: driver_16 - Value Type: <class 'float'>
#     Key: driver_17 - Value Type: <class 'float'>
#     Key: driver_18 - Value Type: <class 'float'>
#     Key: driver_2 - Value Type: <class 'float'>
#     Key: driver_3 - Value Type: <class 'float'>
#     Key: driver_4 - Value Type: <class 'float'>
#     Key: driver_5 - Value Type: <class 'float'>
#     Key: driver_6 - Value Type: <class 'float'>
#     Key: driver_7 - Value Type: <class 'float'>
#     Key: driver_8 - Value Type: <class 'float'>
#     Key: driver_9 - Value Type: <class 'float'>
#   Key: total_distance - Value Type: <class 'float'>
#   Key: num_late_visits - Value Type: <class 'int'>

# %%
import re
# Extract the finishedProcessingAt timestamp
finished_processing_at = solution_data['timing']['finishedProcessingAt']

# Format the timestamp to make it file-name friendly (remove colons, spaces, etc.)
formatted_timestamp = re.sub(r'[:\s]', '-', finished_processing_at)

# %%
# Convert the solution data to a JSON string
json_data = json.dumps(solution_data, indent=4)

# Define your S3 bucket and folder (optional)
bucket_name = 'dispatched-orders'
folder_name = 'optimized-dispatch-raw/'
s3_file_name = f'{folder_name}dispatch_{formatted_timestamp}.json'  # File name in S3

# Upload the JSON string directly to S3
s3_client.put_object(
    Bucket=bucket_name,
    Key=s3_file_name,
    Body=json_data,  # The JSON data as the body
    ContentType='application/json'  # Specify content type as JSON
)

print(f"JSON data uploaded to s3://{bucket_name}/{s3_file_name}")
# Out:
# JSON data uploaded to s3://dispatched-orders/optimized-dispatch-raw/dispatch_2024-10-03T01-31-09.146Z.json

# %%
from datetime import datetime, timedelta
from pyspark.sql.functions import lit, col

# Extract the served 'cus' IDs and finish times from the solution
served_customers = []
for driver, stops in solution_data['output']['solution'].items():
    for stop in stops:
        # Only process stops with customer IDs (which start with 'cus-')
        if stop['location_name'].startswith('cus-'):
            served_customers.append((stop['location_name'], stop['finish_time']))

# Debugging: Print the served customers
print("Served customers:", served_customers)

# Convert the finish_time into a timestamp and add one day
for index, (cus_id, finish_time) in enumerate(served_customers):
    try:
        # Assuming the finish_time is in 'HH:MM' format, append a date and parse it
        finish_time_obj = datetime.strptime(finish_time, '%H:%M')
        updated_finish_time = datetime.now().replace(hour=finish_time_obj.hour, minute=finish_time_obj.minute) + timedelta(days=1)
        served_customers[index] = (cus_id, updated_finish_time)
    except ValueError as e:
        print(f"Error parsing finish_time '{finish_time}' for cus_id '{cus_id}': {e}")

# Debugging: Print served customers after time adjustment
print("Served customers after time adjustment:", served_customers)
# Out:
21, 18, 555304)), ('cus-30e3b389-4422-45f2-9cd2-88786e803733', datetime.datetime(2024, 10, 4, 10, 11, 18, 555314)), ('cus-607eff8c-4ad4-4a2e-8abe-1b72d8be173f', datetime.datetime(2024, 10, 4, 9, 34, 18, 555324)), ('cus-c85c717a-78fd-4c44-b151-14387d4b8d74', datetime.datetime(2024, 10, 4, 9, 35, 18, 555333)), ('cus-2a0cddf4-cfc0-45f8-8502-abe13dee4284', datetime.datetime(2024, 10, 4, 9, 43, 18, 555343)), ('cus-2bdcc414-58ea-4f84-8e3a-e830a68dfdeb', datetime.datetime(2024, 10, 4, 9, 36, 18, 555352)), ('cus-ca693a19-80da-40a1-b8d3-377404f372d6', datetime.datetime(2024, 10, 4, 9, 56, 18, 555361)), ('cus-c7255b5b-f67f-4f66-b5dc-1d340ab2cbeb', datetime.datetime(2024, 10, 4, 10, 9, 18, 555370)), ('cus-6bf87077-5e08-4fd1-838f-f3006e2f58dc', datetime.datetime(2024, 10, 4, 9, 28, 18, 555379)), ('cus-2f527c49-a8e6-4d82-b936-2d6a4e1a752f', datetime.datetime(2024, 10, 4, 10, 8, 18, 555388)), ('cus-c42061b9-ecf7-43ec-b2a3-996da0e347e8', datetime.datetime(2024, 10, 4, 11, 6, 18, 555398)), ('cus-65ca0831-b406-46f3-a6aa-4b5c4fdb9bf0', datetime.datetime(2024, 10, 4, 9, 32, 18, 555407)), ('cus-45aaaea9-81d1-49fc-aba5-35692ba64573', datetime.datetime(2024, 10, 4, 9, 40, 18, 555416)), ('cus-5b9324f6-e59f-403a-9505-802734cb9be5', datetime.datetime(2024, 10, 4, 9, 27, 18, 555426)), ('cus-1e36370f-561f-4079-b666-c2e7723f2c0e', datetime.datetime(2024, 10, 4, 9, 36, 18, 555435)), ('cus-313f79db-bfc4-4775-b765-05525bc0f73f', datetime.datetime(2024, 10, 4, 9, 29, 18, 555443)), ('cus-2260441b-7585-4cff-b1e9-f9787083a80b', datetime.datetime(2024, 10, 4, 9, 32, 18, 555453))]

# %%
from pyspark.sql.functions import lit, col
from delta.tables import DeltaTable

# Function to overwrite Delta table with the updated 'DISPATCHED' records
def overwrite_delta_table(served_customers, delta_table_path):
    # Read the Delta table into a DataFrame
    delta_table = DeltaTable.forPath(spark, delta_table_path)
    df = delta_table.toDF()

    # Create a DataFrame from the served customers list
    served_df = spark.createDataFrame(served_customers, ['served_customer_id', 'updated_finish_time'])

    # Rename the column in served_df to avoid ambiguity during the join
    served_df = served_df.withColumnRenamed('updated_finish_time', 'new_finish_time')

    # Update the records that match the served customers
    updated_df = df.join(served_df, df.customer_id == served_df.served_customer_id, 'inner') \
        .withColumn('status', lit('DISPATCHED')) \
        .withColumn('order_timestamp', col('new_finish_time'))  # Use the renamed column

    # Overwrite only the affected rows in the Delta table
    delta_table.alias('old') \
        .merge(updated_df.alias('new'), 'old.customer_id = new.served_customer_id') \
        .whenMatchedUpdate(set={
            "status": col('new.status'),
            "order_timestamp": col('new.new_finish_time')  # Use the renamed column
        }) \
        .execute()

    # Display the updated Delta table without the extra columns
